# %%
#import psycopg2
import pandas as pd
from sqlalchemy import create_engine, Column, Integer, String, text, TIMESTAMP, func, DECIMAL, ForeignKey, CheckConstraint
from sqlalchemy.ext.declarative import declarative_base
from sqlalchemy.orm import sessionmaker
import os
from pathlib import Path

# %%
# Parámetros de conexión
host = "localhost"
port = "5432"
dbname = "EcommerceDB"
user = "postgres"
password = "postgres123"

# Crear conexión
engine = create_engine(f"postgresql+psycopg2://{user}:{password}@{host}:{port}/{dbname}", echo=True)
Session = sessionmaker(bind=engine)
session = Session()

# %%
Base = declarative_base()

class Usuario(Base):
    __tablename__ = 'usuarios'
    usuarioid = Column(Integer, primary_key=True, autoincrement=True)
    nombre = Column(String(100), nullable=False)
    apellido = Column(String(100), nullable=False)
    dni = Column(String(20), unique=True, nullable=False)
    email = Column(String(255), unique=True, nullable=False)
    contraseña = Column(String(255), nullable=False)
    fecharegistro = Column(TIMESTAMP, server_default=func.current_timestamp())

class Categoria(Base):
    __tablename__ = 'categorias'
    categoriaid = Column(Integer, primary_key=True, autoincrement=True)
    nombre = Column(String(100), nullable=False)
    descripcion = Column(String(255))

class Producto(Base):
    __tablename__ = 'productos'
    productoid = Column(Integer, primary_key=True, autoincrement=True)
    nombre = Column(String(255), nullable=False)
    descripcion = Column(String(255))
    precio = Column(DECIMAL(10, 2), nullable=False)
    stock = Column(Integer, nullable=False)
    categoriaid = Column(Integer, ForeignKey('categorias.categoriaid'), nullable=False)

class Orden(Base):
    __tablename__ = 'ordenes'
    ordenid = Column(Integer, primary_key=True, autoincrement=True)
    usuarioid = Column(Integer, ForeignKey('usuarios.usuarioid'), nullable=False)
    fechaorden = Column(TIMESTAMP, server_default=func.current_timestamp())
    total = Column(DECIMAL(10, 2), nullable=False)
    estado = Column(String(50), server_default='Pendiente')

class DetalleOrden(Base):
    __tablename__ = 'detalleordenes'
    detalleid = Column(Integer, primary_key=True, autoincrement=True)
    ordenid = Column(Integer, ForeignKey('ordenes.ordenid'), nullable=False)
    productoid = Column(Integer, ForeignKey('productos.productoid'), nullable=False)
    cantidad = Column(Integer, nullable=False)
    preciounitario = Column(DECIMAL(10, 2), nullable=False)

class DireccionEnvio(Base):
    __tablename__ = 'direccionesenvio'
    direccionid = Column(Integer, primary_key=True, autoincrement=True)
    usuarioid = Column(Integer, ForeignKey('usuarios.usuarioid'), nullable=False)
    calle = Column(String(255), nullable=False)
    ciudad = Column(String(100), nullable=False)
    departamento = Column(String(100))
    provincia = Column(String(100))
    distrito = Column(String(100))
    estado = Column(String(100))
    codigopostal = Column(String(20))
    pais = Column(String(100), nullable=False)

class Carrito(Base):
    __tablename__ = 'carrito'
    carritoid = Column(Integer, primary_key=True, autoincrement=True)
    usuarioid = Column(Integer, ForeignKey('usuarios.usuarioid'), nullable=False)
    productoid = Column(Integer, ForeignKey('productos.productoid'), nullable=False)
    cantidad = Column(Integer, nullable=False)
    fechaagregado = Column(TIMESTAMP, server_default=func.current_timestamp())

class MetodoPago(Base):
    __tablename__ = 'metodospago'
    metodopagoid = Column(Integer, primary_key=True, autoincrement=True)
    nombre = Column(String(100), nullable=False)
    descripcion = Column(String(255))

class OrdenMetodoPago(Base):
    __tablename__ = 'ordenesmetodospago'
    ordenmetodoid = Column(Integer, primary_key=True, autoincrement=True)
    ordenid = Column(Integer, ForeignKey('ordenes.ordenid'), nullable=False)
    metodopagoid = Column(Integer, ForeignKey('metodospago.metodopagoid'), nullable=False)
    montopagado = Column(DECIMAL(10, 2), nullable=False)

class ReseñaProducto(Base):
    __tablename__ = 'reseñasproductos'
    reseñaid = Column(Integer, primary_key=True, autoincrement=True)
    usuarioid = Column(Integer, ForeignKey('usuarios.usuarioid'), nullable=False)
    productoid = Column(Integer, ForeignKey('productos.productoid'), nullable=False)
    calificacion = Column(Integer, CheckConstraint('calificacion >= 1 AND calificacion <= 5'))
    comentario = Column(String(255))
    fecha = Column(TIMESTAMP, server_default=func.current_timestamp())

class HistorialPago(Base):
    __tablename__ = 'historialpagos'
    pagoid = Column(Integer, primary_key=True, autoincrement=True)
    ordenid = Column(Integer, ForeignKey('ordenes.ordenid'), nullable=False)
    metodopagoid = Column(Integer, ForeignKey('metodospago.metodopagoid'), nullable=False)
    monto = Column(DECIMAL(10, 2), nullable=False)
    fechapago = Column(TIMESTAMP, server_default=func.current_timestamp())
    estadopago = Column(String(50), server_default='Procesando')

Base.metadata.drop_all(engine)
Base.metadata.create_all(engine)
# Out:
# 2025-07-24 13:36:43,715 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-24 13:36:43,718 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relname = %(table_name)s AND pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s, %(param_4)s, %(param_5)s]) AND pg_catalog.pg_table_is_visible(pg_catalog.pg_class.oid) AND pg_catalog.pg_namespace.nspname != %(nspname_1)s
# 2025-07-24 13:36:43,721 INFO sqlalchemy.engine.Engine [cached since 21.43s ago] {'table_name': 'usuarios', 'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'param_4': 'v', 'param_5': 'm', 'nspname_1': 'pg_catalog'}
# 2025-07-24 13:36:43,739 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relname = %(table_name)s AND pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s, %(param_4)s, %(param_5)s]) AND pg_catalog.pg_table_is_visible(pg_catalog.pg_class.oid) AND pg_catalog.pg_namespace.nspname != %(nspname_1)s
# 2025-07-24 13:36:43,741 INFO sqlalchemy.engine.Engine [cached since 21.45s ago] {'table_name': 'categorias', 'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'param_4': 'v', 'param_5': 'm', 'nspname_1': 'pg_catalog'}
# 2025-07-24 13:36:43,749 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relname = %(table_name)s AND pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s, %(param_4)s, %(param_5)s]) AND pg_catalog.pg_table_is_visible(pg_catalog.pg_class.oid) AND pg_catalog.pg_namespace.nspname != %(nspname_1)s
# 2025-07-24 13:36:43,752 INFO sqlalchemy.engine.Engine [cached since 21.46s ago] {'table_name': 'productos', 'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'param_4': 'v', 'param_5': 'm', 'nspname_1': 'pg_catalog'}
# 2025-07-24 13:36:43,757 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relname = %(table_name)s AND pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s, %(param_4)s, %(param_5)s]) AND pg_catalog.pg_table_is_visible(pg_catalog.pg_class.oid) AND pg_catalog.pg_namespace.nspname != %(nspname_1)s
# 2025-07-24 13:36:43,761 INFO sqlalchemy.engine.Engine [cached since 21.47s ago] {'table_name': 'ordenes', 'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'param_4': 'v', 'param_5': 'm', 'nspname_1': 'pg_catalog'}
# 2025-07-24 13:36:43,767 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relname = %(table_name)s AND pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s, %(param_4)s, %(param_5)s]) AND pg_catalog.pg_table_is_visible(pg_catalog.pg_class.oid) AND pg_catalog.pg_namespace.nspname != %(nspname_1)s
# 2025-07-24 13:36:43,768 INFO sqlalchemy.engine.Engine [cached since 21.47s ago] {'table_name': 'detalleordenes', 'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'param_4': 'v', 'param_5': 'm', 'nspname_1': 'pg_catalog'}
# 2025-07-24 13:36:43,772 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relname = %(table_name)s AND pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s, %(param_4)s, %(param_5)s]) AND pg_catalog.pg_table_is_visible(pg_catalog.pg_class.oid) AND pg_catalog.pg_namespace.nspname != %(nspname_1)s
# 2025-07-24 13:36:43,775 INFO sqlalchemy.engine.Engine [cached since 21.48s ago] {'table_name': 'direccionesenvio', 'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'param_4': 'v', 'param_5': 'm', 'nspname_1': 'pg_catalog'}
# 2025-07-24 13:36:43,780 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relname = %(table_name)s AND pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s, %(param_4)s, %(param_5)s]) AND pg_catalog.pg_table_is_visible(pg_catalog.pg_class.oid) AND pg_catalog.pg_namespace.nspname != %(nspname_1)s
# 2025-07-24 13:36:43,781 INFO sqlalchemy.engine.Engine [cached since 21.49s ago] {'table_name': 'carrito', 'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'param_4': 'v', 'param_5': 'm', 'nspname_1': 'pg_catalog'}
# 2025-07-24 13:36:43,786 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relname = %(table_name)s AND pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s, %(param_4)s, %(param_5)s]) AND pg_catalog.pg_table_is_visible(pg_catalog.pg_class.oid) AND pg_catalog.pg_namespace.nspname != %(nspname_1)s
# 2025-07-24 13:36:43,790 INFO sqlalchemy.engine.Engine [cached since 21.49s ago] {'table_name': 'metodospago', 'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'param_4': 'v', 'param_5': 'm', 'nspname_1': 'pg_catalog'}
# 2025-07-24 13:36:43,796 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relname = %(table_name)s AND pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s, %(param_4)s, %(param_5)s]) AND pg_catalog.pg_table_is_visible(pg_catalog.pg_class.oid) AND pg_catalog.pg_namespace.nspname != %(nspname_1)s
# 2025-07-24 13:36:43,799 INFO sqlalchemy.engine.Engine [cached since 21.5s ago] {'table_name': 'ordenesmetodospago', 'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'param_4': 'v', 'param_5': 'm', 'nspname_1': 'pg_catalog'}
# 2025-07-24 13:36:43,804 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relname = %(table_name)s AND pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s, %(param_4)s, %(param_5)s]) AND pg_catalog.pg_table_is_visible(pg_catalog.pg_class.oid) AND pg_catalog.pg_namespace.nspname != %(nspname_1)s
# 2025-07-24 13:36:43,805 INFO sqlalchemy.engine.Engine [cached since 21.51s ago] {'table_name': 'reseñasproductos', 'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'param_4': 'v', 'param_5': 'm', 'nspname_1': 'pg_catalog'}
# 2025-07-24 13:36:43,810 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relname = %(table_name)s AND pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s, %(param_4)s, %(param_5)s]) AND pg_catalog.pg_table_is_visible(pg_catalog.pg_class.oid) AND pg_catalog.pg_namespace.nspname != %(nspname_1)s
# 2025-07-24 13:36:43,811 INFO sqlalchemy.engine.Engine [cached since 21.52s ago] {'table_name': 'historialpagos', 'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'param_4': 'v', 'param_5': 'm', 'nspname_1': 'pg_catalog'}
# 2025-07-24 13:36:43,814 INFO sqlalchemy.engine.Engine
# DROP TABLE historialpagos
# 2025-07-24 13:36:43,815 INFO sqlalchemy.engine.Engine [no key 0.00063s] {}
# 2025-07-24 13:36:43,818 INFO sqlalchemy.engine.Engine
# DROP TABLE "reseñasproductos"
# 2025-07-24 13:36:43,819 INFO sqlalchemy.engine.Engine [no key 0.00076s] {}
# 2025-07-24 13:36:43,824 INFO sqlalchemy.engine.Engine
# DROP TABLE ordenesmetodospago
# 2025-07-24 13:36:43,824 INFO sqlalchemy.engine.Engine [no key 0.00085s] {}
# 2025-07-24 13:36:43,827 INFO sqlalchemy.engine.Engine
# DROP TABLE carrito
# 2025-07-24 13:36:43,828 INFO sqlalchemy.engine.Engine [no key 0.00091s] {}
# 2025-07-24 13:36:43,831 INFO sqlalchemy.engine.Engine
# DROP TABLE detalleordenes
# 2025-07-24 13:36:43,832 INFO sqlalchemy.engine.Engine [no key 0.00114s] {}
# 2025-07-24 13:36:43,836 INFO sqlalchemy.engine.Engine
# DROP TABLE direccionesenvio
# 2025-07-24 13:36:43,838 INFO sqlalchemy.engine.Engine [no key 0.00108s] {}
# 2025-07-24 13:36:43,840 INFO sqlalchemy.engine.Engine
# DROP TABLE ordenes
# 2025-07-24 13:36:43,841 INFO sqlalchemy.engine.Engine [no key 0.00062s] {}
# 2025-07-24 13:36:43,846 INFO sqlalchemy.engine.Engine
# DROP TABLE productos
# 2025-07-24 13:36:43,847 INFO sqlalchemy.engine.Engine [no key 0.00097s] {}
# C:\Users\gabriel.b.alvarez\AppData\Local\Temp\ipykernel_20552\2515579819.py:1: MovedIn20Warning: The ``declarative_base()`` function is now available as sqlalchemy.orm.declarative_base(). (deprecated since: 2.0) (Background on SQLAlchemy 2.0 at: https://sqlalche.me/e/b8d9)
#   Base = declarative_base()
# 2025-07-24 13:36:43,850 INFO sqlalchemy.engine.Engine
# DROP TABLE metodospago
# 2025-07-24 13:36:43,850 INFO sqlalchemy.engine.Engine [no key 0.00084s] {}
# 2025-07-24 13:36:43,855 INFO sqlalchemy.engine.Engine
# DROP TABLE categorias
# 2025-07-24 13:36:43,856 INFO sqlalchemy.engine.Engine [no key 0.00114s] {}
# 2025-07-24 13:36:43,860 INFO sqlalchemy.engine.Engine
# DROP TABLE usuarios
# 2025-07-24 13:36:43,863 INFO sqlalchemy.engine.Engine [no key 0.00229s] {}
# 2025-07-24 13:36:43,865 INFO sqlalchemy.engine.Engine COMMIT
# 2025-07-24 13:36:43,878 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-24 13:36:43,879 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relname = %(table_name)s AND pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s, %(param_4)s, %(param_5)s]) AND pg_catalog.pg_table_is_visible(pg_catalog.pg_class.oid) AND pg_catalog.pg_namespace.nspname != %(nspname_1)s
# 2025-07-24 13:36:43,880 INFO sqlalchemy.engine.Engine [cached since 21.58s ago] {'table_name': 'usuarios', 'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'param_4': 'v', 'param_5': 'm', 'nspname_1': 'pg_catalog'}
# 2025-07-24 13:36:43,889 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relname = %(table_name)s AND pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s, %(param_4)s, %(param_5)s]) AND pg_catalog.pg_table_is_visible(pg_catalog.pg_class.oid) AND pg_catalog.pg_namespace.nspname != %(nspname_1)s
# 2025-07-24 13:36:43,891 INFO sqlalchemy.engine.Engine [cached since 21.6s ago] {'table_name': 'categorias', 'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'param_4': 'v', 'param_5': 'm', 'nspname_1': 'pg_catalog'}
# 2025-07-24 13:36:43,899 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relname = %(table_name)s AND pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s, %(param_4)s, %(param_5)s]) AND pg_catalog.pg_table_is_visible(pg_catalog.pg_class.oid) AND pg_catalog.pg_namespace.nspname != %(nspname_1)s
# 2025-07-24 13:36:43,901 INFO sqlalchemy.engine.Engine [cached since 21.61s ago] {'table_name': 'productos', 'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'param_4': 'v', 'param_5': 'm', 'nspname_1': 'pg_catalog'}
# 2025-07-24 13:36:43,908 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relname = %(table_name)s AND pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s, %(param_4)s, %(param_5)s]) AND pg_catalog.pg_table_is_visible(pg_catalog.pg_class.oid) AND pg_catalog.pg_namespace.nspname != %(nspname_1)s
# 2025-07-24 13:36:43,910 INFO sqlalchemy.engine.Engine [cached since 21.61s ago] {'table_name': 'ordenes', 'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'param_4': 'v', 'param_5': 'm', 'nspname_1': 'pg_catalog'}
# 2025-07-24 13:36:43,913 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relname = %(table_name)s AND pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s, %(param_4)s, %(param_5)s]) AND pg_catalog.pg_table_is_visible(pg_catalog.pg_class.oid) AND pg_catalog.pg_namespace.nspname != %(nspname_1)s
# 2025-07-24 13:36:43,914 INFO sqlalchemy.engine.Engine [cached since 21.62s ago] {'table_name': 'detalleordenes', 'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'param_4': 'v', 'param_5': 'm', 'nspname_1': 'pg_catalog'}
# 2025-07-24 13:36:43,917 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relname = %(table_name)s AND pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s, %(param_4)s, %(param_5)s]) AND pg_catalog.pg_table_is_visible(pg_catalog.pg_class.oid) AND pg_catalog.pg_namespace.nspname != %(nspname_1)s
# 2025-07-24 13:36:43,918 INFO sqlalchemy.engine.Engine [cached since 21.62s ago] {'table_name': 'direccionesenvio', 'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'param_4': 'v', 'param_5': 'm', 'nspname_1': 'pg_catalog'}
# 2025-07-24 13:36:43,924 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relname = %(table_name)s AND pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s, %(param_4)s, %(param_5)s]) AND pg_catalog.pg_table_is_visible(pg_catalog.pg_class.oid) AND pg_catalog.pg_namespace.nspname != %(nspname_1)s
# 2025-07-24 13:36:43,927 INFO sqlalchemy.engine.Engine [cached since 21.63s ago] {'table_name': 'carrito', 'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'param_4': 'v', 'param_5': 'm', 'nspname_1': 'pg_catalog'}
# 2025-07-24 13:36:43,930 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relname = %(table_name)s AND pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s, %(param_4)s, %(param_5)s]) AND pg_catalog.pg_table_is_visible(pg_catalog.pg_class.oid) AND pg_catalog.pg_namespace.nspname != %(nspname_1)s
# 2025-07-24 13:36:43,931 INFO sqlalchemy.engine.Engine [cached since 21.64s ago] {'table_name': 'metodospago', 'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'param_4': 'v', 'param_5': 'm', 'nspname_1': 'pg_catalog'}
# 2025-07-24 13:36:43,935 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relname = %(table_name)s AND pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s, %(param_4)s, %(param_5)s]) AND pg_catalog.pg_table_is_visible(pg_catalog.pg_class.oid) AND pg_catalog.pg_namespace.nspname != %(nspname_1)s
# 2025-07-24 13:36:43,937 INFO sqlalchemy.engine.Engine [cached since 21.64s ago] {'table_name': 'ordenesmetodospago', 'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'param_4': 'v', 'param_5': 'm', 'nspname_1': 'pg_catalog'}
# 2025-07-24 13:36:43,944 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relname = %(table_name)s AND pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s, %(param_4)s, %(param_5)s]) AND pg_catalog.pg_table_is_visible(pg_catalog.pg_class.oid) AND pg_catalog.pg_namespace.nspname != %(nspname_1)s
# 2025-07-24 13:36:43,946 INFO sqlalchemy.engine.Engine [cached since 21.65s ago] {'table_name': 'reseñasproductos', 'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'param_4': 'v', 'param_5': 'm', 'nspname_1': 'pg_catalog'}
# 2025-07-24 13:36:43,949 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relname = %(table_name)s AND pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s, %(param_4)s, %(param_5)s]) AND pg_catalog.pg_table_is_visible(pg_catalog.pg_class.oid) AND pg_catalog.pg_namespace.nspname != %(nspname_1)s
# 2025-07-24 13:36:43,951 INFO sqlalchemy.engine.Engine [cached since 21.66s ago] {'table_name': 'historialpagos', 'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'param_4': 'v', 'param_5': 'm', 'nspname_1': 'pg_catalog'}
# 2025-07-24 13:36:43,958 INFO sqlalchemy.engine.Engine
# CREATE TABLE usuarios (
# 	usuarioid SERIAL NOT NULL,
# 	nombre VARCHAR(100) NOT NULL,
# 	apellido VARCHAR(100) NOT NULL,
# 	dni VARCHAR(20) NOT NULL,
# 	email VARCHAR(255) NOT NULL,
# 	"contraseña" VARCHAR(255) NOT NULL,
# 	fecharegistro TIMESTAMP WITHOUT TIME ZONE DEFAULT CURRENT_TIMESTAMP,
# 	PRIMARY KEY (usuarioid),
# 	UNIQUE (dni),
# 	UNIQUE (email)
# )
#
#
# 2025-07-24 13:36:43,960 INFO sqlalchemy.engine.Engine [no key 0.00191s] {}
# 2025-07-24 13:36:43,967 INFO sqlalchemy.engine.Engine
# CREATE TABLE categorias (
# 	categoriaid SERIAL NOT NULL,
# 	nombre VARCHAR(100) NOT NULL,
# 	descripcion VARCHAR(255),
# 	PRIMARY KEY (categoriaid)
# )
#
#
# 2025-07-24 13:36:43,968 INFO sqlalchemy.engine.Engine [no key 0.00125s] {}
# 2025-07-24 13:36:43,979 INFO sqlalchemy.engine.Engine
# CREATE TABLE metodospago (
# 	metodopagoid SERIAL NOT NULL,
# 	nombre VARCHAR(100) NOT NULL,
# 	descripcion VARCHAR(255),
# 	PRIMARY KEY (metodopagoid)
# )
#
#
# 2025-07-24 13:36:43,981 INFO sqlalchemy.engine.Engine [no key 0.00209s] {}
# 2025-07-24 13:36:43,990 INFO sqlalchemy.engine.Engine
# CREATE TABLE productos (
# 	productoid SERIAL NOT NULL,
# 	nombre VARCHAR(255) NOT NULL,
# 	descripcion VARCHAR(255),
# 	precio DECIMAL(10, 2) NOT NULL,
# 	stock INTEGER NOT NULL,
# 	categoriaid INTEGER NOT NULL,
# 	PRIMARY KEY (productoid),
# 	FOREIGN KEY(categoriaid) REFERENCES categorias (categoriaid)
# )
#
#
# 2025-07-24 13:36:43,992 INFO sqlalchemy.engine.Engine [no key 0.00206s] {}
# 2025-07-24 13:36:43,999 INFO sqlalchemy.engine.Engine
# CREATE TABLE ordenes (
# 	ordenid SERIAL NOT NULL,
# 	usuarioid INTEGER NOT NULL,
# 	fechaorden TIMESTAMP WITHOUT TIME ZONE DEFAULT CURRENT_TIMESTAMP,
# 	total DECIMAL(10, 2) NOT NULL,
# 	estado VARCHAR(50) DEFAULT 'Pendiente',
# 	PRIMARY KEY (ordenid),
# 	FOREIGN KEY(usuarioid) REFERENCES usuarios (usuarioid)
# )
#
#
# 2025-07-24 13:36:44,000 INFO sqlalchemy.engine.Engine [no key 0.00129s] {}
# 2025-07-24 13:36:44,007 INFO sqlalchemy.engine.Engine
# CREATE TABLE direccionesenvio (
# 	direccionid SERIAL NOT NULL,
# 	usuarioid INTEGER NOT NULL,
# 	calle VARCHAR(255) NOT NULL,
# 	ciudad VARCHAR(100) NOT NULL,
# 	departamento VARCHAR(100),
# 	provincia VARCHAR(100),
# 	distrito VARCHAR(100),
# 	estado VARCHAR(100),
# 	codigopostal VARCHAR(20),
# 	pais VARCHAR(100) NOT NULL,
# 	PRIMARY KEY (direccionid),
# 	FOREIGN KEY(usuarioid) REFERENCES usuarios (usuarioid)
# )
#
#
# 2025-07-24 13:36:44,008 INFO sqlalchemy.engine.Engine [no key 0.00079s] {}
# 2025-07-24 13:36:44,012 INFO sqlalchemy.engine.Engine
# CREATE TABLE detalleordenes (
# 	detalleid SERIAL NOT NULL,
# 	ordenid INTEGER NOT NULL,
# 	productoid INTEGER NOT NULL,
# 	cantidad INTEGER NOT NULL,
# 	preciounitario DECIMAL(10, 2) NOT NULL,
# 	PRIMARY KEY (detalleid),
# 	FOREIGN KEY(ordenid) REFERENCES ordenes (ordenid),
# 	FOREIGN KEY(productoid) REFERENCES productos (productoid)
# )
#
#
# 2025-07-24 13:36:44,013 INFO sqlalchemy.engine.Engine [no key 0.00088s] {}
# 2025-07-24 13:36:44,018 INFO sqlalchemy.engine.Engine
# CREATE TABLE carrito (
# 	carritoid SERIAL NOT NULL,
# 	usuarioid INTEGER NOT NULL,
# 	productoid INTEGER NOT NULL,
# 	cantidad INTEGER NOT NULL,
# 	fechaagregado TIMESTAMP WITHOUT TIME ZONE DEFAULT CURRENT_TIMESTAMP,
# 	PRIMARY KEY (carritoid),
# 	FOREIGN KEY(usuarioid) REFERENCES usuarios (usuarioid),
# 	FOREIGN KEY(productoid) REFERENCES productos (productoid)
# )
#
#
# 2025-07-24 13:36:44,019 INFO sqlalchemy.engine.Engine [no key 0.00116s] {}
# 2025-07-24 13:36:44,024 INFO sqlalchemy.engine.Engine
# CREATE TABLE ordenesmetodospago (
# 	ordenmetodoid SERIAL NOT NULL,
# 	ordenid INTEGER NOT NULL,
# 	metodopagoid INTEGER NOT NULL,
# 	montopagado DECIMAL(10, 2) NOT NULL,
# 	PRIMARY KEY (ordenmetodoid),
# 	FOREIGN KEY(ordenid) REFERENCES ordenes (ordenid),
# 	FOREIGN KEY(metodopagoid) REFERENCES metodospago (metodopagoid)
# )
#
#
# 2025-07-24 13:36:44,024 INFO sqlalchemy.engine.Engine [no key 0.00076s] {}
# 2025-07-24 13:36:44,028 INFO sqlalchemy.engine.Engine
# CREATE TABLE "reseñasproductos" (
# 	"reseñaid" SERIAL NOT NULL,
# 	usuarioid INTEGER NOT NULL,
# 	productoid INTEGER NOT NULL,
# 	calificacion INTEGER CHECK (calificacion >= 1 AND calificacion <= 5),
# 	comentario VARCHAR(255),
# 	fecha TIMESTAMP WITHOUT TIME ZONE DEFAULT CURRENT_TIMESTAMP,
# 	PRIMARY KEY ("reseñaid"),
# 	FOREIGN KEY(usuarioid) REFERENCES usuarios (usuarioid),
# 	FOREIGN KEY(productoid) REFERENCES productos (productoid)
# )
#
#
# 2025-07-24 13:36:44,029 INFO sqlalchemy.engine.Engine [no key 0.00107s] {}
# 2025-07-24 13:36:44,037 INFO sqlalchemy.engine.Engine
# CREATE TABLE historialpagos (
# 	pagoid SERIAL NOT NULL,
# 	ordenid INTEGER NOT NULL,
# 	metodopagoid INTEGER NOT NULL,
# 	monto DECIMAL(10, 2) NOT NULL,
# 	fechapago TIMESTAMP WITHOUT TIME ZONE DEFAULT CURRENT_TIMESTAMP,
# 	estadopago VARCHAR(50) DEFAULT 'Procesando',
# 	PRIMARY KEY (pagoid),
# 	FOREIGN KEY(ordenid) REFERENCES ordenes (ordenid),
# 	FOREIGN KEY(metodopagoid) REFERENCES metodospago (metodopagoid)
# )
#
#
# 2025-07-24 13:36:44,039 INFO sqlalchemy.engine.Engine [no key 0.00199s] {}
# 2025-07-24 13:36:44,044 INFO sqlalchemy.engine.Engine COMMIT

# %%
#ruta_base = r"resources\csv"
ruta_base = Path.cwd().parents[1] / "resources" / "csv"

map_csv_table = {
    "2.Usuarios.csv": "usuarios",
    "3.Categorias.csv": "categorias",
    "4.Productos.csv": "productos",
    "5.ordenes.csv": "ordenes",
    "6.detalle_ordenes.csv": "detalleordenes",
    "7.direcciones_envio.csv": "direccionesenvio",
    "8.carrito.csv": "carrito",
    "9.metodos_pago.csv": "metodospago",
    "10.ordenes_metodospago.csv": "ordenesmetodospago",
    "11.resenas_productos.csv": "reseñasproductos",
    "12.historial_pagos.csv": "historialpagos"
}

for file_name, table_name in map_csv_table.items():
    #file_path = os.path.join(ruta_base, file_name)
    file_path = ruta_base / file_name
    df = pd.read_csv(file_path)

    # Proceso de Wrangling:
    # Con esto mostrado, se analiza --> Tipos de datos, Nulos, Duplicados
    print("Shape:")
    print(df.shape)
    print("Info:")
    print(df.info())
    print("Head:")
    print(df.head())

    # Eliminacion de duplicados:
    df = df.drop_duplicates()

    # Rellenar o eliminar nulos:
    df.dropna()

    # Estandarizacion de nombres de columnas:
    df.columns = df.columns.str.lower()

    # Carga de datos
    df.to_sql(table_name, con=engine, if_exists='append', index=False)
# Out:
# Shape:
# (1000, 5)
# Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Nombre      1000 non-null   object
#  1   Apellido    1000 non-null   object
#  2   DNI         1000 non-null   int64
#  3   Email       1000 non-null   object
#  4   Contraseña  1000 non-null   object
# dtypes: int64(1), object(4)
# memory usage: 39.2+ KB
# None
# Head:
#          Nombre   Apellido       DNI                             Email  \
# 0       Encarna    Donaire  49877134       encarna.donaire1@correo.com
# 1  Jose Ignacio    Canales  98778810  jose ignacio.canales2@correo.com
# 2          José  Sebastián  80095714        josé.sebastián3@correo.com
# 3      Priscila      Vilar  94128750        priscila.vilar4@correo.com
# 4      Epifanio       Ríos  62958342         epifanio.ríos5@correo.com
#
#       Contraseña
# 0  Contraseña123
# 1  Contraseña123
# 2  Contraseña123
# 3  Contraseña123
# 4  Contraseña123
# 2025-07-24 13:40:42,850 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-24 13:40:42,852 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relname = %(table_name)s AND pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s, %(param_4)s, %(param_5)s]) AND pg_catalog.pg_table_is_visible(pg_catalog.pg_class.oid) AND pg_catalog.pg_namespace.nspname != %(nspname_1)s
# 2025-07-24 13:40:42,853 INFO sqlalchemy.engine.Engine [cached since 260.6s ago] {'table_name': 'usuarios', 'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'param_4': 'v', 'param_5': 'm', 'nspname_1': 'pg_catalog'}
# 2025-07-24 13:40:42,868 INFO sqlalchemy.engine.Engine INSERT INTO usuarios (nombre, apellido, dni, email, "contraseña") VALUES (%(nombre__0)s, %(apellido__0)s, %(dni__0)s, %(email__0)s, %(contraseña__0)s), (%(nombre__1)s, %(apellido__1)s, %(dni__1)s, %(email__1)s, %(contraseña__1)s), (%(nombre__2)s, %(a ... 88171 characters truncated ... eña__998)s), (%(nombre__999)s, %(apellido__999)s, %(dni__999)s, %(email__999)s, %(contraseña__999)s)
# 2025-07-24 13:40:42,870 INFO sqlalchemy.engine.Engine [generated in 0.00252s (insertmanyvalues) 1/1 (unordered)] {'contraseña__0': 'Contraseña123', 'apellido__0': 'Donaire', 'dni__0': 49877134, 'email__0': 'encarna.donaire1@correo.com', 'nombre__0': 'Encarna', 'contraseña__1': 'Contraseña123', 'apellido__1': 'Canales', 'dni__1': 98778810, 'email__1': 'jose ignacio.canales2@correo.com', 'nombre__1': 'Jose Ignacio', 'contraseña__2': 'Contraseña123', 'apellido__2': 'Sebastián', 'dni__2': 80095714, 'email__2': 'josé.sebastián3@correo.com', 'nombre__2': 'José', 'contraseña__3': 'Contraseña123', 'apellido__3': 'Vilar', 'dni__3': 94128750, 'email__3': 'priscila.vilar4@correo.com', 'nombre__3': 'Priscila', 'contraseña__4': 'Contraseña123', 'apellido__4': 'Ríos', 'dni__4': 62958342, 'email__4': 'epifanio.ríos5@correo.com', 'nombre__4': 'Epifanio', 'contraseña__5': 'Contraseña123', 'apellido__5': 'Sastre', 'dni__5': 49889941, 'email__5': 'cipriano.sastre6@correo.com', 'nombre__5': 'Cipriano', 'contraseña__6': 'Contraseña123', 'apellido__6': 'Alcalá', 'dni__6': 55549753, 'email__6': 'gerónimo.alcalá7@correo.com', 'nombre__6': 'Gerónimo', 'contraseña__7': 'Contraseña123', 'apellido__7': 'Estévez', 'dni__7': 93023722, 'email__7': 'odalis.estévez8@correo.com', 'nombre__7': 'Odalis', 'contraseña__8': 'Contraseña123', 'apellido__8': 'Prada', 'dni__8': 67127313, 'email__8': 'clara.prada9@correo.com', 'nombre__8': 'Clara', 'contraseña__9': 'Contraseña123', 'apellido__9': 'Espada', 'dni__9': 38665213, 'email__9': 'azahara.espada10@correo.com', 'nombre__9': 'Azahara' ... 4900 parameters truncated ... 'contraseña__990': 'Contraseña123', 'apellido__990': 'Chico', 'dni__990': 39819237, 'email__990': 'severiano.chico991@correo.com', 'nombre__990': 'Severiano', 'contraseña__991': 'Contraseña123', 'apellido__991': 'Vidal', 'dni__991': 87172235, 'email__991': 'guadalupe.vidal992@correo.com', 'nombre__991': 'Guadalupe', 'contraseña__992': 'Contraseña123', 'apellido__992': 'Pellicer', 'dni__992': 47044788, 'email__992': 'wálter.pellicer993@correo.com', 'nombre__992': 'Wálter', 'contraseña__993': 'Contraseña123', 'apellido__993': 'Font', 'dni__993': 38624354, 'email__993': 'loreto.font994@correo.com', 'nombre__993': 'Loreto', 'contraseña__994': 'Contraseña123', 'apellido__994': 'Zurita', 'dni__994': 19012099, 'email__994': 'sebastian.zurita995@correo.com', 'nombre__994': 'Sebastian', 'contraseña__995': 'Contraseña123', 'apellido__995': 'Rubio', 'dni__995': 23078527, 'email__995': 'adelina.rubio996@correo.com', 'nombre__995': 'Adelina', 'contraseña__996': 'Contraseña123', 'apellido__996': 'Villa', 'dni__996': 66428333, 'email__996': 'lino.villa997@correo.com', 'nombre__996': 'Lino', 'contraseña__997': 'Contraseña123', 'apellido__997': 'León', 'dni__997': 91873586, 'email__997': 'goyo.león998@correo.com', 'nombre__997': 'Goyo', 'contraseña__998': 'Contraseña123', 'apellido__998': 'Cerdá', 'dni__998': 77891983, 'email__998': 'pastora.cerdá999@correo.com', 'nombre__998': 'Pastora', 'contraseña__999': 'Contraseña123', 'apellido__999': 'Fabregat', 'dni__999': 31210164, 'email__999': 'marianela.fabregat1000@correo.com', 'nombre__999': 'Marianela'}
# 2025-07-24 13:40:42,906 INFO sqlalchemy.engine.Engine COMMIT
# Shape:
# (12, 2)
# Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12 entries, 0 to 11
# Data columns (total 2 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Nombre       12 non-null     object
#  1   Descripcion  12 non-null     object
# dtypes: object(2)
# memory usage: 324.0+ bytes
# None
# Head:
#                        Nombre  \
# 0                 Electrónica
# 1                        Moda
# 2              Hogar y Cocina
# 3       Deportes y Aire Libre
# 4  Belleza y Cuidado Personal
#
#                                          Descripcion
# 0  Teléfonos, computadoras, accesorios y disposit...
# 1  Ropa, calzado, bolsos y accesorios para hombre...
# 2  Muebles, electrodomésticos, utensilios y decor...
# 3  Equipamiento, ropa deportiva y artículos para ...
# 4  Cosméticos, productos para el cabello, piel y ...
# 2025-07-24 13:40:42,918 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-24 13:40:42,919 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relname = %(table_name)s AND pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s, %(param_4)s, %(param_5)s]) AND pg_catalog.pg_table_is_visible(pg_catalog.pg_class.oid) AND pg_catalog.pg_namespace.nspname != %(nspname_1)s
# 2025-07-24 13:40:42,921 INFO sqlalchemy.engine.Engine [cached since 260.6s ago] {'table_name': 'categorias', 'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'param_4': 'v', 'param_5': 'm', 'nspname_1': 'pg_catalog'}
# 2025-07-24 13:40:42,926 INFO sqlalchemy.engine.Engine INSERT INTO categorias (nombre, descripcion) VALUES (%(nombre__0)s, %(descripcion__0)s), (%(nombre__1)s, %(descripcion__1)s), (%(nombre__2)s, %(descripcion__2)s), (%(nombre__3)s, %(descripcion__3)s), (%(nombre__4)s, %(descripcion__4)s), (%(nombre__5)s, %(descripcion__5)s), (%(nombre__6)s, %(descripcion__6)s), (%(nombre__7)s, %(descripcion__7)s), (%(nombre__8)s, %(descripcion__8)s), (%(nombre__9)s, %(descripcion__9)s), (%(nombre__10)s, %(descripcion__10)s), (%(nombre__11)s, %(descripcion__11)s)
# 2025-07-24 13:40:42,928 INFO sqlalchemy.engine.Engine [generated in 0.00007s (insertmanyvalues) 1/1 (unordered)] {'descripcion__0': 'Teléfonos, computadoras, accesorios y dispositivos inteligentes', 'nombre__0': 'Electrónica', 'descripcion__1': 'Ropa, calzado, bolsos y accesorios para hombres, mujeres y niños', 'nombre__1': 'Moda', 'descripcion__2': 'Muebles, electrodomésticos, utensilios y decoración', 'nombre__2': 'Hogar y Cocina', 'descripcion__3': 'Equipamiento, ropa deportiva y artículos para actividades al aire libre', 'nombre__3': 'Deportes y Aire Libre', 'descripcion__4': 'Cosméticos, productos para el cabello, piel y aseo personal', 'nombre__4': 'Belleza y Cuidado Personal', 'descripcion__5': 'Juguetes para todas las edades, juegos de mesa, didácticos y electrónicos', 'nombre__5': 'Juguetes y Juegos', 'descripcion__6': 'Accesorios y repuestos para vehículos', 'nombre__6': 'Automotriz', 'descripcion__7': 'Libros, cuadernos, útiles escolares y de oficina', 'nombre__7': 'Libros y Papelería', 'descripcion__8': 'Vitaminas, suplementos y productos médicos', 'nombre__8': 'Salud', 'descripcion__9': 'Alimentos, juguetes y productos para el cuidado de mascotas', 'nombre__9': 'Mascotas', 'descripcion__10': 'Innovaciones tecnológicas y productos novedosos', 'nombre__10': 'Tecnología y Gadgets', 'descripcion__11': 'Consolas, juegos físicos y digitales, accesorios gamer', 'nombre__11': 'Videojuegos'}
# 2025-07-24 13:40:42,932 INFO sqlalchemy.engine.Engine COMMIT
# Shape:
# (36, 5)
# Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36 entries, 0 to 35
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Nombre       36 non-null     object
#  1   Descripcion  36 non-null     object
#  2   Precio       36 non-null     float64
#  3   Stock        36 non-null     int64
#  4   CategoriaID  36 non-null     int64
# dtypes: float64(1), int64(2), object(2)
# memory usage: 1.5+ KB
# None
# Head:
#                        Nombre  \
# 0       Smartphone Galaxy A54
# 1     Laptop Dell Inspiron 15
# 2  Auriculares Bluetooth Sony
# 3      Camiseta Básica Hombre
# 4          Jeans Skinny Mujer
#
#                                          Descripcion  Precio  Stock  \
# 0  Teléfono inteligente con pantalla AMOLED y cám...  349.99     50
# 1  Laptop para trabajo y estudio con procesador I...  799.00     30
# 2  Auriculares inalámbricos con cancelación de ru...  129.99    100
# 3  Camiseta de algodón 100% disponible en varias ...   14.99    200
# 4              Jeans corte skinny de mezclilla azul.   39.99    150
#
#    CategoriaID
# 0            1
# 1            1
# 2            1
# 3            2
# 4            2
# 2025-07-24 13:40:42,943 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-24 13:40:42,945 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relname = %(table_name)s AND pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s, %(param_4)s, %(param_5)s]) AND pg_catalog.pg_table_is_visible(pg_catalog.pg_class.oid) AND pg_catalog.pg_namespace.nspname != %(nspname_1)s
# 2025-07-24 13:40:42,946 INFO sqlalchemy.engine.Engine [cached since 260.6s ago] {'table_name': 'productos', 'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'param_4': 'v', 'param_5': 'm', 'nspname_1': 'pg_catalog'}
# 2025-07-24 13:40:42,951 INFO sqlalchemy.engine.Engine INSERT INTO productos (nombre, descripcion, precio, stock, categoriaid) VALUES (%(nombre__0)s, %(descripcion__0)s, %(precio__0)s, %(stock__0)s, %(categoriaid__0)s), (%(nombre__1)s, %(descripcion__1)s, %(precio__1)s, %(stock__1)s, %(categoriaid__1)s), ... 2953 characters truncated ... id__34)s), (%(nombre__35)s, %(descripcion__35)s, %(precio__35)s, %(stock__35)s, %(categoriaid__35)s)
# 2025-07-24 13:40:42,952 INFO sqlalchemy.engine.Engine [generated in 0.00012s (insertmanyvalues) 1/1 (unordered)] {'categoriaid__0': 1, 'precio__0': 349.99, 'descripcion__0': 'Teléfono inteligente con pantalla AMOLED y cámara triple.', 'stock__0': 50, 'nombre__0': 'Smartphone Galaxy A54', 'categoriaid__1': 1, 'precio__1': 799.0, 'descripcion__1': 'Laptop para trabajo y estudio con procesador Intel i5.', 'stock__1': 30, 'nombre__1': 'Laptop Dell Inspiron 15', 'categoriaid__2': 1, 'precio__2': 129.99, 'descripcion__2': 'Auriculares inalámbricos con cancelación de ruido.', 'stock__2': 100, 'nombre__2': 'Auriculares Bluetooth Sony', 'categoriaid__3': 2, 'precio__3': 14.99, 'descripcion__3': 'Camiseta de algodón 100% disponible en varias tallas.', 'stock__3': 200, 'nombre__3': 'Camiseta Básica Hombre', 'categoriaid__4': 2, 'precio__4': 39.99, 'descripcion__4': 'Jeans corte skinny de mezclilla azul.', 'stock__4': 150, 'nombre__4': 'Jeans Skinny Mujer', 'categoriaid__5': 2, 'precio__5': 59.99, 'descripcion__5': 'Calzado deportivo para running o uso casual.', 'stock__5': 80, 'nombre__5': 'Zapatillas Deportivas', 'categoriaid__6': 3, 'precio__6': 19.99, 'descripcion__6': 'Sartén de aluminio con recubrimiento antiadherente.', 'stock__6': 120, 'nombre__6': 'Sartén Antiadherente 24cm', 'categoriaid__7': 3, 'precio__7': 49.99, 'descripcion__7': 'Juego de sábanas de algodón para cama tamaño Queen.', 'stock__7': 60, 'nombre__7': 'Juego de Sábanas Queen', 'categoriaid__8': 3, 'precio__8': 25.5, 'descripcion__8': 'Lámpara LED con ajuste de intensidad.', 'stock__8': 75, 'nombre__8': 'Lámpara de Escritorio LED', 'categoriaid__9': 4, 'precio__9': 299.0, 'descripcion__9': 'Bicicleta para adulto con cambios Shimano.', 'stock__9': 20, 'nombre__9': 'Bicicleta Montaña Aro 29' ... 80 parameters truncated ... 'categoriaid__26': 9, 'precio__26': 5.25, 'descripcion__26': 'Gel antibacterial con 70% de alcohol.', 'stock__26': 200, 'nombre__26': 'Alcohol en Gel 500ml', 'categoriaid__27': 10, 'precio__27': 32.0, 'descripcion__27': 'Croquetas para perros adultos sabor carne.', 'stock__27': 90, 'nombre__27': 'Alimento para Perro 10kg', 'categoriaid__28': 10, 'precio__28': 25.99, 'descripcion__28': 'Caja sanitaria con tapa y filtro.', 'stock__28': 40, 'nombre__28': 'Arenero para Gato', 'categoriaid__29': 10, 'precio__29': 8.5, 'descripcion__29': 'Juguete resistente para perros medianos.', 'stock__29': 110, 'nombre__29': 'Juguete Mordedor Canino', 'categoriaid__30': 11, 'precio__30': 44.9, 'descripcion__30': 'Pulsera inteligente con monitor de ritmo cardíaco.', 'stock__30': 100, 'nombre__30': 'Smartwatch Xiaomi Mi Band 8', 'categoriaid__31': 11, 'precio__31': 75.0, 'descripcion__31': 'Proyector portátil para películas o presentaciones.', 'stock__31': 35, 'nombre__31': 'Mini Proyector LED', 'categoriaid__32': 11, 'precio__32': 29.99, 'descripcion__32': 'Batería externa de carga rápida USB-C.', 'stock__32': 70, 'nombre__32': 'Power Bank 20,000mAh', 'categoriaid__33': 12, 'precio__33': 549.99, 'descripcion__33': 'Consola de videojuegos de última generación.', 'stock__33': 20, 'nombre__33': 'Consola PlayStation 5', 'categoriaid__34': 12, 'precio__34': 59.99, 'descripcion__34': 'Mando inalámbrico con vibración y grip.', 'stock__34': 50, 'nombre__34': 'Control Xbox Series X', 'categoriaid__35': 12, 'precio__35': 69.99, 'descripcion__35': 'Juego de fútbol con licencias oficiales.', 'stock__35': 30, 'nombre__35': 'Juego FIFA 24 - PS5'}
# 2025-07-24 13:40:42,958 INFO sqlalchemy.engine.Engine COMMIT
# Shape:
# (10000, 4)
# Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   UsuarioID   10000 non-null  int64
#  1   FechaOrden  10000 non-null  object
#  2   Total       10000 non-null  float64
#  3   Estado      10000 non-null  object
# dtypes: float64(1), int64(1), object(2)
# memory usage: 312.6+ KB
# None
# Head:
#    UsuarioID           FechaOrden   Total      Estado
# 0        153  2024-09-09 09:10:27  393.81     Enviado
# 1        810  2024-09-29 09:10:27  918.85  Completado
# 2        404  2024-11-03 09:10:27  391.29   Pendiente
# 3         52  2024-09-14 09:10:27  250.03   Cancelado
# 4        811  2025-04-11 09:10:27  983.13  Completado
# 2025-07-24 13:40:42,979 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-24 13:40:42,980 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relname = %(table_name)s AND pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s, %(param_4)s, %(param_5)s]) AND pg_catalog.pg_table_is_visible(pg_catalog.pg_class.oid) AND pg_catalog.pg_namespace.nspname != %(nspname_1)s
# 2025-07-24 13:40:42,981 INFO sqlalchemy.engine.Engine [cached since 260.7s ago] {'table_name': 'ordenes', 'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'param_4': 'v', 'param_5': 'm', 'nspname_1': 'pg_catalog'}
# 2025-07-24 13:40:43,008 INFO sqlalchemy.engine.Engine INSERT INTO ordenes (usuarioid, fechaorden, total, estado) VALUES (%(usuarioid__0)s, %(fechaorden__0)s, %(total__0)s, %(estado__0)s), (%(usuarioid__1)s, %(fechaorden__1)s, %(total__1)s, %(estado__1)s), (%(usuarioid__2)s, %(fechaorden__2)s, %(total__2 ... 75274 characters truncated ... _998)s, %(estado__998)s), (%(usuarioid__999)s, %(fechaorden__999)s, %(total__999)s, %(estado__999)s)
# 2025-07-24 13:40:43,010 INFO sqlalchemy.engine.Engine [generated in 0.01610s (insertmanyvalues) 1/10 (unordered)] {'total__0': 393.81, 'fechaorden__0': '2024-09-09 09:10:27', 'estado__0': 'Enviado', 'usuarioid__0': 153, 'total__1': 918.85, 'fechaorden__1': '2024-09-29 09:10:27', 'estado__1': 'Completado', 'usuarioid__1': 810, 'total__2': 391.29, 'fechaorden__2': '2024-11-03 09:10:27', 'estado__2': 'Pendiente', 'usuarioid__2': 404, 'total__3': 250.03, 'fechaorden__3': '2024-09-14 09:10:27', 'estado__3': 'Cancelado', 'usuarioid__3': 52, 'total__4': 983.13, 'fechaorden__4': '2025-04-11 09:10:27', 'estado__4': 'Completado', 'usuarioid__4': 811, 'total__5': 713.98, 'fechaorden__5': '2025-06-26 09:10:27', 'estado__5': 'Pendiente', 'usuarioid__5': 500, 'total__6': 540.25, 'fechaorden__6': '2024-08-14 09:10:27', 'estado__6': 'Enviado', 'usuarioid__6': 357, 'total__7': 972.6, 'fechaorden__7': '2025-04-17 09:10:27', 'estado__7': 'Completado', 'usuarioid__7': 486, 'total__8': 78.71, 'fechaorden__8': '2024-08-03 09:10:27', 'estado__8': 'Pendiente', 'usuarioid__8': 862, 'total__9': 218.77, 'fechaorden__9': '2024-08-26 09:10:27', 'estado__9': 'Completado', 'usuarioid__9': 58, 'total__10': 939.88, 'fechaorden__10': '2025-06-10 09:10:27', 'estado__10': 'Enviado', 'usuarioid__10': 561, 'total__11': 894.36, 'fechaorden__11': '2024-11-15 09:10:27', 'estado__11': 'Cancelado', 'usuarioid__11': 146, 'total__12': 399.09, 'fechaorden__12': '2024-09-26 09:10:27' ... 3900 parameters truncated ... 'estado__987': 'Completado', 'usuarioid__987': 35, 'total__988': 946.55, 'fechaorden__988': '2025-05-10 09:10:27', 'estado__988': 'Pendiente', 'usuarioid__988': 936, 'total__989': 120.17, 'fechaorden__989': '2025-03-30 09:10:27', 'estado__989': 'Enviado', 'usuarioid__989': 937, 'total__990': 158.39, 'fechaorden__990': '2025-01-23 09:10:27', 'estado__990': 'Pendiente', 'usuarioid__990': 635, 'total__991': 901.3, 'fechaorden__991': '2024-09-16 09:10:27', 'estado__991': 'Pendiente', 'usuarioid__991': 616, 'total__992': 599.03, 'fechaorden__992': '2025-06-26 09:10:27', 'estado__992': 'Pendiente', 'usuarioid__992': 280, 'total__993': 584.39, 'fechaorden__993': '2024-07-21 09:10:27', 'estado__993': 'Pendiente', 'usuarioid__993': 393, 'total__994': 60.33, 'fechaorden__994': '2024-08-09 09:10:27', 'estado__994': 'Cancelado', 'usuarioid__994': 306, 'total__995': 721.14, 'fechaorden__995': '2025-06-18 09:10:27', 'estado__995': 'Pendiente', 'usuarioid__995': 899, 'total__996': 467.19, 'fechaorden__996': '2024-11-30 09:10:27', 'estado__996': 'Cancelado', 'usuarioid__996': 21, 'total__997': 804.1, 'fechaorden__997': '2025-04-20 09:10:27', 'estado__997': 'Pendiente', 'usuarioid__997': 474, 'total__998': 990.13, 'fechaorden__998': '2024-10-05 09:10:27', 'estado__998': 'Enviado', 'usuarioid__998': 728, 'total__999': 163.6, 'fechaorden__999': '2024-07-10 09:10:27', 'estado__999': 'Completado', 'usuarioid__999': 42}
# 2025-07-24 13:40:43,033 INFO sqlalchemy.engine.Engine INSERT INTO ordenes (usuarioid, fechaorden, total, estado) VALUES (%(usuarioid__0)s, %(fechaorden__0)s, %(total__0)s, %(estado__0)s), (%(usuarioid__1)s, %(fechaorden__1)s, %(total__1)s, %(estado__1)s), (%(usuarioid__2)s, %(fechaorden__2)s, %(total__2 ... 75274 characters truncated ... _998)s, %(estado__998)s), (%(usuarioid__999)s, %(fechaorden__999)s, %(total__999)s, %(estado__999)s)
# 2025-07-24 13:40:43,034 INFO sqlalchemy.engine.Engine [insertmanyvalues 2/10 (unordered)] {'total__0': 973.81, 'fechaorden__0': '2025-05-12 09:10:27', 'estado__0': 'Completado', 'usuarioid__0': 381, 'total__1': 225.28, 'fechaorden__1': '2024-11-09 09:10:27', 'estado__1': 'Cancelado', 'usuarioid__1': 907, 'total__2': 201.77, 'fechaorden__2': '2025-05-29 09:10:27', 'estado__2': 'Completado', 'usuarioid__2': 277, 'total__3': 180.58, 'fechaorden__3': '2025-06-03 09:10:27', 'estado__3': 'Enviado', 'usuarioid__3': 498, 'total__4': 587.97, 'fechaorden__4': '2024-07-02 09:10:27', 'estado__4': 'Enviado', 'usuarioid__4': 295, 'total__5': 43.6, 'fechaorden__5': '2025-03-08 09:10:27', 'estado__5': 'Pendiente', 'usuarioid__5': 513, 'total__6': 889.16, 'fechaorden__6': '2024-07-18 09:10:27', 'estado__6': 'Cancelado', 'usuarioid__6': 480, 'total__7': 442.38, 'fechaorden__7': '2024-12-23 09:10:27', 'estado__7': 'Cancelado', 'usuarioid__7': 477, 'total__8': 727.73, 'fechaorden__8': '2025-06-23 09:10:27', 'estado__8': 'Cancelado', 'usuarioid__8': 586, 'total__9': 770.72, 'fechaorden__9': '2024-07-21 09:10:27', 'estado__9': 'Completado', 'usuarioid__9': 952, 'total__10': 974.16, 'fechaorden__10': '2024-10-08 09:10:27', 'estado__10': 'Cancelado', 'usuarioid__10': 151, 'total__11': 79.5, 'fechaorden__11': '2024-12-01 09:10:27', 'estado__11': 'Pendiente', 'usuarioid__11': 93, 'total__12': 297.42, 'fechaorden__12': '2025-02-05 09:10:27' ... 3900 parameters truncated ... 'estado__987': 'Completado', 'usuarioid__987': 27, 'total__988': 652.42, 'fechaorden__988': '2025-01-23 09:10:27', 'estado__988': 'Completado', 'usuarioid__988': 348, 'total__989': 966.91, 'fechaorden__989': '2024-08-13 09:10:27', 'estado__989': 'Pendiente', 'usuarioid__989': 648, 'total__990': 197.65, 'fechaorden__990': '2025-02-18 09:10:27', 'estado__990': 'Pendiente', 'usuarioid__990': 207, 'total__991': 977.79, 'fechaorden__991': '2025-05-16 09:10:27', 'estado__991': 'Cancelado', 'usuarioid__991': 720, 'total__992': 514.62, 'fechaorden__992': '2024-11-28 09:10:27', 'estado__992': 'Enviado', 'usuarioid__992': 645, 'total__993': 122.48, 'fechaorden__993': '2025-03-02 09:10:27', 'estado__993': 'Enviado', 'usuarioid__993': 609, 'total__994': 44.5, 'fechaorden__994': '2025-01-26 09:10:27', 'estado__994': 'Completado', 'usuarioid__994': 248, 'total__995': 956.15, 'fechaorden__995': '2024-12-23 09:10:27', 'estado__995': 'Enviado', 'usuarioid__995': 685, 'total__996': 837.92, 'fechaorden__996': '2025-03-01 09:10:27', 'estado__996': 'Completado', 'usuarioid__996': 15, 'total__997': 987.26, 'fechaorden__997': '2025-04-03 09:10:27', 'estado__997': 'Enviado', 'usuarioid__997': 283, 'total__998': 331.34, 'fechaorden__998': '2025-05-09 09:10:27', 'estado__998': 'Enviado', 'usuarioid__998': 628, 'total__999': 107.79, 'fechaorden__999': '2024-08-20 09:10:27', 'estado__999': 'Enviado', 'usuarioid__999': 431}
# 2025-07-24 13:40:43,054 INFO sqlalchemy.engine.Engine INSERT INTO ordenes (usuarioid, fechaorden, total, estado) VALUES (%(usuarioid__0)s, %(fechaorden__0)s, %(total__0)s, %(estado__0)s), (%(usuarioid__1)s, %(fechaorden__1)s, %(total__1)s, %(estado__1)s), (%(usuarioid__2)s, %(fechaorden__2)s, %(total__2 ... 75274 characters truncated ... _998)s, %(estado__998)s), (%(usuarioid__999)s, %(fechaorden__999)s, %(total__999)s, %(estado__999)s)
# 2025-07-24 13:40:43,056 INFO sqlalchemy.engine.Engine [insertmanyvalues 3/10 (unordered)] {'total__0': 344.58, 'fechaorden__0': '2024-12-13 09:10:27', 'estado__0': 'Enviado', 'usuarioid__0': 34, 'total__1': 917.51, 'fechaorden__1': '2025-06-27 09:10:27', 'estado__1': 'Cancelado', 'usuarioid__1': 378, 'total__2': 379.07, 'fechaorden__2': '2025-01-02 09:10:27', 'estado__2': 'Pendiente', 'usuarioid__2': 186, 'total__3': 616.29, 'fechaorden__3': '2025-05-16 09:10:27', 'estado__3': 'Pendiente', 'usuarioid__3': 551, 'total__4': 645.72, 'fechaorden__4': '2024-09-11 09:10:27', 'estado__4': 'Completado', 'usuarioid__4': 16, 'total__5': 143.51, 'fechaorden__5': '2024-09-13 09:10:27', 'estado__5': 'Cancelado', 'usuarioid__5': 282, 'total__6': 466.85, 'fechaorden__6': '2025-06-17 09:10:27', 'estado__6': 'Cancelado', 'usuarioid__6': 631, 'total__7': 867.87, 'fechaorden__7': '2024-07-08 09:10:27', 'estado__7': 'Cancelado', 'usuarioid__7': 825, 'total__8': 643.42, 'fechaorden__8': '2025-06-18 09:10:27', 'estado__8': 'Pendiente', 'usuarioid__8': 778, 'total__9': 937.23, 'fechaorden__9': '2025-03-05 09:10:27', 'estado__9': 'Cancelado', 'usuarioid__9': 945, 'total__10': 555.19, 'fechaorden__10': '2025-04-11 09:10:27', 'estado__10': 'Enviado', 'usuarioid__10': 68, 'total__11': 165.66, 'fechaorden__11': '2024-12-12 09:10:27', 'estado__11': 'Enviado', 'usuarioid__11': 812, 'total__12': 379.51, 'fechaorden__12': '2024-12-04 09:10:27' ... 3900 parameters truncated ... 'estado__987': 'Pendiente', 'usuarioid__987': 314, 'total__988': 381.84, 'fechaorden__988': '2024-10-23 09:10:27', 'estado__988': 'Cancelado', 'usuarioid__988': 801, 'total__989': 704.7, 'fechaorden__989': '2024-09-08 09:10:27', 'estado__989': 'Completado', 'usuarioid__989': 697, 'total__990': 290.01, 'fechaorden__990': '2024-07-14 09:10:27', 'estado__990': 'Completado', 'usuarioid__990': 578, 'total__991': 192.25, 'fechaorden__991': '2024-12-28 09:10:27', 'estado__991': 'Completado', 'usuarioid__991': 592, 'total__992': 739.28, 'fechaorden__992': '2025-06-19 09:10:27', 'estado__992': 'Cancelado', 'usuarioid__992': 161, 'total__993': 159.48, 'fechaorden__993': '2024-12-10 09:10:27', 'estado__993': 'Pendiente', 'usuarioid__993': 941, 'total__994': 347.4, 'fechaorden__994': '2024-10-02 09:10:27', 'estado__994': 'Completado', 'usuarioid__994': 664, 'total__995': 157.48, 'fechaorden__995': '2024-10-30 09:10:27', 'estado__995': 'Cancelado', 'usuarioid__995': 43, 'total__996': 968.64, 'fechaorden__996': '2024-07-01 09:10:27', 'estado__996': 'Enviado', 'usuarioid__996': 743, 'total__997': 906.75, 'fechaorden__997': '2025-03-04 09:10:27', 'estado__997': 'Enviado', 'usuarioid__997': 864, 'total__998': 944.83, 'fechaorden__998': '2025-01-29 09:10:27', 'estado__998': 'Completado', 'usuarioid__998': 107, 'total__999': 798.51, 'fechaorden__999': '2024-09-12 09:10:27', 'estado__999': 'Cancelado', 'usuarioid__999': 299}
# 2025-07-24 13:40:43,077 INFO sqlalchemy.engine.Engine INSERT INTO ordenes (usuarioid, fechaorden, total, estado) VALUES (%(usuarioid__0)s, %(fechaorden__0)s, %(total__0)s, %(estado__0)s), (%(usuarioid__1)s, %(fechaorden__1)s, %(total__1)s, %(estado__1)s), (%(usuarioid__2)s, %(fechaorden__2)s, %(total__2 ... 75274 characters truncated ... _998)s, %(estado__998)s), (%(usuarioid__999)s, %(fechaorden__999)s, %(total__999)s, %(estado__999)s)
# 2025-07-24 13:40:43,079 INFO sqlalchemy.engine.Engine [insertmanyvalues 4/10 (unordered)] {'total__0': 26.22, 'fechaorden__0': '2025-05-17 09:10:27', 'estado__0': 'Completado', 'usuarioid__0': 985, 'total__1': 613.56, 'fechaorden__1': '2024-10-17 09:10:27', 'estado__1': 'Pendiente', 'usuarioid__1': 210, 'total__2': 960.93, 'fechaorden__2': '2025-04-10 09:10:27', 'estado__2': 'Pendiente', 'usuarioid__2': 746, 'total__3': 50.16, 'fechaorden__3': '2024-07-15 09:10:27', 'estado__3': 'Enviado', 'usuarioid__3': 351, 'total__4': 987.66, 'fechaorden__4': '2024-09-15 09:10:27', 'estado__4': 'Enviado', 'usuarioid__4': 964, 'total__5': 415.45, 'fechaorden__5': '2024-09-20 09:10:27', 'estado__5': 'Completado', 'usuarioid__5': 455, 'total__6': 430.34, 'fechaorden__6': '2025-01-03 09:10:27', 'estado__6': 'Cancelado', 'usuarioid__6': 398, 'total__7': 763.39, 'fechaorden__7': '2024-09-18 09:10:27', 'estado__7': 'Cancelado', 'usuarioid__7': 439, 'total__8': 57.07, 'fechaorden__8': '2025-06-18 09:10:27', 'estado__8': 'Pendiente', 'usuarioid__8': 558, 'total__9': 69.38, 'fechaorden__9': '2024-11-30 09:10:27', 'estado__9': 'Cancelado', 'usuarioid__9': 255, 'total__10': 786.72, 'fechaorden__10': '2025-06-11 09:10:27', 'estado__10': 'Completado', 'usuarioid__10': 421, 'total__11': 783.78, 'fechaorden__11': '2024-07-03 09:10:27', 'estado__11': 'Pendiente', 'usuarioid__11': 595, 'total__12': 249.18, 'fechaorden__12': '2024-08-16 09:10:27' ... 3900 parameters truncated ... 'estado__987': 'Enviado', 'usuarioid__987': 118, 'total__988': 716.68, 'fechaorden__988': '2025-04-13 09:10:27', 'estado__988': 'Pendiente', 'usuarioid__988': 319, 'total__989': 338.83, 'fechaorden__989': '2024-08-14 09:10:27', 'estado__989': 'Enviado', 'usuarioid__989': 152, 'total__990': 161.4, 'fechaorden__990': '2025-06-02 09:10:27', 'estado__990': 'Enviado', 'usuarioid__990': 182, 'total__991': 388.74, 'fechaorden__991': '2025-05-04 09:10:27', 'estado__991': 'Cancelado', 'usuarioid__991': 655, 'total__992': 639.77, 'fechaorden__992': '2024-12-18 09:10:27', 'estado__992': 'Enviado', 'usuarioid__992': 842, 'total__993': 547.75, 'fechaorden__993': '2025-02-18 09:10:27', 'estado__993': 'Enviado', 'usuarioid__993': 631, 'total__994': 722.0, 'fechaorden__994': '2025-03-12 09:10:27', 'estado__994': 'Pendiente', 'usuarioid__994': 656, 'total__995': 368.41, 'fechaorden__995': '2025-06-16 09:10:27', 'estado__995': 'Completado', 'usuarioid__995': 920, 'total__996': 318.17, 'fechaorden__996': '2024-09-20 09:10:27', 'estado__996': 'Completado', 'usuarioid__996': 900, 'total__997': 207.82, 'fechaorden__997': '2025-06-21 09:10:27', 'estado__997': 'Cancelado', 'usuarioid__997': 452, 'total__998': 691.72, 'fechaorden__998': '2025-06-28 09:10:27', 'estado__998': 'Enviado', 'usuarioid__998': 418, 'total__999': 739.12, 'fechaorden__999': '2025-02-13 09:10:27', 'estado__999': 'Cancelado', 'usuarioid__999': 951}
# 2025-07-24 13:40:43,103 INFO sqlalchemy.engine.Engine INSERT INTO ordenes (usuarioid, fechaorden, total, estado) VALUES (%(usuarioid__0)s, %(fechaorden__0)s, %(total__0)s, %(estado__0)s), (%(usuarioid__1)s, %(fechaorden__1)s, %(total__1)s, %(estado__1)s), (%(usuarioid__2)s, %(fechaorden__2)s, %(total__2 ... 75274 characters truncated ... _998)s, %(estado__998)s), (%(usuarioid__999)s, %(fechaorden__999)s, %(total__999)s, %(estado__999)s)
# 2025-07-24 13:40:43,104 INFO sqlalchemy.engine.Engine [insertmanyvalues 5/10 (unordered)] {'total__0': 288.31, 'fechaorden__0': '2024-10-16 09:10:27', 'estado__0': 'Pendiente', 'usuarioid__0': 865, 'total__1': 172.31, 'fechaorden__1': '2024-07-21 09:10:27', 'estado__1': 'Enviado', 'usuarioid__1': 922, 'total__2': 670.43, 'fechaorden__2': '2024-08-20 09:10:27', 'estado__2': 'Enviado', 'usuarioid__2': 267, 'total__3': 591.61, 'fechaorden__3': '2025-01-21 09:10:27', 'estado__3': 'Enviado', 'usuarioid__3': 415, 'total__4': 283.24, 'fechaorden__4': '2024-08-25 09:10:27', 'estado__4': 'Pendiente', 'usuarioid__4': 609, 'total__5': 789.57, 'fechaorden__5': '2024-10-31 09:10:27', 'estado__5': 'Cancelado', 'usuarioid__5': 216, 'total__6': 218.86, 'fechaorden__6': '2024-10-05 09:10:27', 'estado__6': 'Completado', 'usuarioid__6': 25, 'total__7': 640.0, 'fechaorden__7': '2024-09-02 09:10:27', 'estado__7': 'Cancelado', 'usuarioid__7': 293, 'total__8': 509.15, 'fechaorden__8': '2024-11-02 09:10:27', 'estado__8': 'Cancelado', 'usuarioid__8': 553, 'total__9': 535.62, 'fechaorden__9': '2024-08-17 09:10:27', 'estado__9': 'Completado', 'usuarioid__9': 419, 'total__10': 402.46, 'fechaorden__10': '2024-11-29 09:10:27', 'estado__10': 'Enviado', 'usuarioid__10': 823, 'total__11': 543.18, 'fechaorden__11': '2025-01-28 09:10:27', 'estado__11': 'Enviado', 'usuarioid__11': 309, 'total__12': 244.83, 'fechaorden__12': '2024-08-27 09:10:27' ... 3900 parameters truncated ... 'estado__987': 'Pendiente', 'usuarioid__987': 644, 'total__988': 53.03, 'fechaorden__988': '2024-07-04 09:10:27', 'estado__988': 'Pendiente', 'usuarioid__988': 683, 'total__989': 179.91, 'fechaorden__989': '2024-11-03 09:10:27', 'estado__989': 'Cancelado', 'usuarioid__989': 706, 'total__990': 669.46, 'fechaorden__990': '2025-03-12 09:10:27', 'estado__990': 'Pendiente', 'usuarioid__990': 126, 'total__991': 523.7, 'fechaorden__991': '2025-05-16 09:10:27', 'estado__991': 'Cancelado', 'usuarioid__991': 429, 'total__992': 325.87, 'fechaorden__992': '2024-08-29 09:10:27', 'estado__992': 'Cancelado', 'usuarioid__992': 379, 'total__993': 949.36, 'fechaorden__993': '2025-04-17 09:10:27', 'estado__993': 'Completado', 'usuarioid__993': 106, 'total__994': 540.23, 'fechaorden__994': '2024-11-04 09:10:27', 'estado__994': 'Cancelado', 'usuarioid__994': 321, 'total__995': 466.92, 'fechaorden__995': '2025-03-26 09:10:27', 'estado__995': 'Completado', 'usuarioid__995': 32, 'total__996': 32.05, 'fechaorden__996': '2025-05-17 09:10:27', 'estado__996': 'Completado', 'usuarioid__996': 266, 'total__997': 582.25, 'fechaorden__997': '2025-02-18 09:10:27', 'estado__997': 'Pendiente', 'usuarioid__997': 20, 'total__998': 593.75, 'fechaorden__998': '2024-09-16 09:10:27', 'estado__998': 'Cancelado', 'usuarioid__998': 595, 'total__999': 244.72, 'fechaorden__999': '2025-06-03 09:10:27', 'estado__999': 'Pendiente', 'usuarioid__999': 444}
# 2025-07-24 13:40:43,124 INFO sqlalchemy.engine.Engine INSERT INTO ordenes (usuarioid, fechaorden, total, estado) VALUES (%(usuarioid__0)s, %(fechaorden__0)s, %(total__0)s, %(estado__0)s), (%(usuarioid__1)s, %(fechaorden__1)s, %(total__1)s, %(estado__1)s), (%(usuarioid__2)s, %(fechaorden__2)s, %(total__2 ... 75274 characters truncated ... _998)s, %(estado__998)s), (%(usuarioid__999)s, %(fechaorden__999)s, %(total__999)s, %(estado__999)s)
# 2025-07-24 13:40:43,125 INFO sqlalchemy.engine.Engine [insertmanyvalues 6/10 (unordered)] {'total__0': 918.48, 'fechaorden__0': '2025-06-17 09:10:27', 'estado__0': 'Enviado', 'usuarioid__0': 595, 'total__1': 429.58, 'fechaorden__1': '2025-01-22 09:10:27', 'estado__1': 'Cancelado', 'usuarioid__1': 803, 'total__2': 56.78, 'fechaorden__2': '2025-06-19 09:10:27', 'estado__2': 'Cancelado', 'usuarioid__2': 528, 'total__3': 402.01, 'fechaorden__3': '2024-12-08 09:10:27', 'estado__3': 'Enviado', 'usuarioid__3': 158, 'total__4': 388.63, 'fechaorden__4': '2024-09-25 09:10:27', 'estado__4': 'Enviado', 'usuarioid__4': 748, 'total__5': 948.13, 'fechaorden__5': '2024-11-23 09:10:27', 'estado__5': 'Completado', 'usuarioid__5': 378, 'total__6': 667.88, 'fechaorden__6': '2025-01-22 09:10:27', 'estado__6': 'Pendiente', 'usuarioid__6': 964, 'total__7': 153.59, 'fechaorden__7': '2025-03-06 09:10:27', 'estado__7': 'Enviado', 'usuarioid__7': 376, 'total__8': 896.21, 'fechaorden__8': '2024-12-25 09:10:27', 'estado__8': 'Pendiente', 'usuarioid__8': 709, 'total__9': 625.55, 'fechaorden__9': '2024-07-09 09:10:27', 'estado__9': 'Cancelado', 'usuarioid__9': 763, 'total__10': 496.67, 'fechaorden__10': '2025-03-07 09:10:27', 'estado__10': 'Pendiente', 'usuarioid__10': 810, 'total__11': 513.03, 'fechaorden__11': '2025-01-25 09:10:27', 'estado__11': 'Completado', 'usuarioid__11': 864, 'total__12': 957.87, 'fechaorden__12': '2025-01-08 09:10:27' ... 3900 parameters truncated ... 'estado__987': 'Enviado', 'usuarioid__987': 763, 'total__988': 919.65, 'fechaorden__988': '2025-04-03 09:10:27', 'estado__988': 'Pendiente', 'usuarioid__988': 846, 'total__989': 604.98, 'fechaorden__989': '2024-08-01 09:10:27', 'estado__989': 'Enviado', 'usuarioid__989': 31, 'total__990': 632.61, 'fechaorden__990': '2025-02-05 09:10:27', 'estado__990': 'Cancelado', 'usuarioid__990': 780, 'total__991': 518.8, 'fechaorden__991': '2025-05-31 09:10:27', 'estado__991': 'Pendiente', 'usuarioid__991': 837, 'total__992': 156.21, 'fechaorden__992': '2024-12-26 09:10:27', 'estado__992': 'Enviado', 'usuarioid__992': 119, 'total__993': 112.55, 'fechaorden__993': '2025-04-30 09:10:27', 'estado__993': 'Completado', 'usuarioid__993': 454, 'total__994': 45.72, 'fechaorden__994': '2024-12-20 09:10:27', 'estado__994': 'Completado', 'usuarioid__994': 335, 'total__995': 88.27, 'fechaorden__995': '2025-04-20 09:10:27', 'estado__995': 'Pendiente', 'usuarioid__995': 704, 'total__996': 932.58, 'fechaorden__996': '2024-11-03 09:10:27', 'estado__996': 'Pendiente', 'usuarioid__996': 270, 'total__997': 403.54, 'fechaorden__997': '2024-10-08 09:10:27', 'estado__997': 'Cancelado', 'usuarioid__997': 255, 'total__998': 716.89, 'fechaorden__998': '2025-01-05 09:10:27', 'estado__998': 'Cancelado', 'usuarioid__998': 230, 'total__999': 727.86, 'fechaorden__999': '2024-07-06 09:10:27', 'estado__999': 'Enviado', 'usuarioid__999': 603}
# 2025-07-24 13:40:43,147 INFO sqlalchemy.engine.Engine INSERT INTO ordenes (usuarioid, fechaorden, total, estado) VALUES (%(usuarioid__0)s, %(fechaorden__0)s, %(total__0)s, %(estado__0)s), (%(usuarioid__1)s, %(fechaorden__1)s, %(total__1)s, %(estado__1)s), (%(usuarioid__2)s, %(fechaorden__2)s, %(total__2 ... 75274 characters truncated ... _998)s, %(estado__998)s), (%(usuarioid__999)s, %(fechaorden__999)s, %(total__999)s, %(estado__999)s)
# 2025-07-24 13:40:43,148 INFO sqlalchemy.engine.Engine [insertmanyvalues 7/10 (unordered)] {'total__0': 788.86, 'fechaorden__0': '2024-09-03 09:10:27', 'estado__0': 'Completado', 'usuarioid__0': 580, 'total__1': 535.03, 'fechaorden__1': '2024-09-18 09:10:27', 'estado__1': 'Completado', 'usuarioid__1': 851, 'total__2': 117.52, 'fechaorden__2': '2025-01-23 09:10:27', 'estado__2': 'Pendiente', 'usuarioid__2': 944, 'total__3': 29.07, 'fechaorden__3': '2025-05-07 09:10:27', 'estado__3': 'Completado', 'usuarioid__3': 599, 'total__4': 687.21, 'fechaorden__4': '2024-07-15 09:10:27', 'estado__4': 'Enviado', 'usuarioid__4': 471, 'total__5': 158.93, 'fechaorden__5': '2025-02-21 09:10:27', 'estado__5': 'Cancelado', 'usuarioid__5': 728, 'total__6': 662.86, 'fechaorden__6': '2024-07-31 09:10:27', 'estado__6': 'Cancelado', 'usuarioid__6': 742, 'total__7': 711.97, 'fechaorden__7': '2024-07-21 09:10:27', 'estado__7': 'Cancelado', 'usuarioid__7': 787, 'total__8': 216.89, 'fechaorden__8': '2024-10-23 09:10:27', 'estado__8': 'Completado', 'usuarioid__8': 236, 'total__9': 179.35, 'fechaorden__9': '2024-07-13 09:10:27', 'estado__9': 'Completado', 'usuarioid__9': 625, 'total__10': 607.38, 'fechaorden__10': '2025-03-24 09:10:27', 'estado__10': 'Enviado', 'usuarioid__10': 750, 'total__11': 479.69, 'fechaorden__11': '2024-09-18 09:10:27', 'estado__11': 'Enviado', 'usuarioid__11': 140, 'total__12': 742.47, 'fechaorden__12': '2024-08-25 09:10:27' ... 3900 parameters truncated ... 'estado__987': 'Pendiente', 'usuarioid__987': 833, 'total__988': 122.67, 'fechaorden__988': '2024-09-13 09:10:27', 'estado__988': 'Completado', 'usuarioid__988': 292, 'total__989': 129.14, 'fechaorden__989': '2024-08-14 09:10:27', 'estado__989': 'Enviado', 'usuarioid__989': 69, 'total__990': 276.61, 'fechaorden__990': '2025-01-08 09:10:27', 'estado__990': 'Cancelado', 'usuarioid__990': 308, 'total__991': 226.54, 'fechaorden__991': '2025-06-18 09:10:27', 'estado__991': 'Cancelado', 'usuarioid__991': 590, 'total__992': 344.22, 'fechaorden__992': '2025-01-09 09:10:27', 'estado__992': 'Enviado', 'usuarioid__992': 369, 'total__993': 668.73, 'fechaorden__993': '2024-09-15 09:10:27', 'estado__993': 'Completado', 'usuarioid__993': 647, 'total__994': 209.47, 'fechaorden__994': '2024-12-17 09:10:27', 'estado__994': 'Pendiente', 'usuarioid__994': 1000, 'total__995': 505.67, 'fechaorden__995': '2024-10-21 09:10:27', 'estado__995': 'Completado', 'usuarioid__995': 822, 'total__996': 565.99, 'fechaorden__996': '2024-09-10 09:10:27', 'estado__996': 'Cancelado', 'usuarioid__996': 3, 'total__997': 945.55, 'fechaorden__997': '2025-06-01 09:10:27', 'estado__997': 'Enviado', 'usuarioid__997': 744, 'total__998': 590.34, 'fechaorden__998': '2025-02-23 09:10:27', 'estado__998': 'Pendiente', 'usuarioid__998': 479, 'total__999': 467.76, 'fechaorden__999': '2024-11-08 09:10:27', 'estado__999': 'Enviado', 'usuarioid__999': 912}
# 2025-07-24 13:40:43,170 INFO sqlalchemy.engine.Engine INSERT INTO ordenes (usuarioid, fechaorden, total, estado) VALUES (%(usuarioid__0)s, %(fechaorden__0)s, %(total__0)s, %(estado__0)s), (%(usuarioid__1)s, %(fechaorden__1)s, %(total__1)s, %(estado__1)s), (%(usuarioid__2)s, %(fechaorden__2)s, %(total__2 ... 75274 characters truncated ... _998)s, %(estado__998)s), (%(usuarioid__999)s, %(fechaorden__999)s, %(total__999)s, %(estado__999)s)
# 2025-07-24 13:40:43,172 INFO sqlalchemy.engine.Engine [insertmanyvalues 8/10 (unordered)] {'total__0': 113.73, 'fechaorden__0': '2025-04-13 09:10:27', 'estado__0': 'Cancelado', 'usuarioid__0': 269, 'total__1': 603.3, 'fechaorden__1': '2025-06-16 09:10:27', 'estado__1': 'Pendiente', 'usuarioid__1': 951, 'total__2': 745.52, 'fechaorden__2': '2024-09-29 09:10:27', 'estado__2': 'Completado', 'usuarioid__2': 908, 'total__3': 241.27, 'fechaorden__3': '2024-12-06 09:10:27', 'estado__3': 'Enviado', 'usuarioid__3': 730, 'total__4': 623.41, 'fechaorden__4': '2024-11-26 09:10:27', 'estado__4': 'Completado', 'usuarioid__4': 645, 'total__5': 448.29, 'fechaorden__5': '2024-10-25 09:10:27', 'estado__5': 'Pendiente', 'usuarioid__5': 927, 'total__6': 210.37, 'fechaorden__6': '2024-10-16 09:10:27', 'estado__6': 'Cancelado', 'usuarioid__6': 181, 'total__7': 982.28, 'fechaorden__7': '2025-05-07 09:10:27', 'estado__7': 'Pendiente', 'usuarioid__7': 916, 'total__8': 882.87, 'fechaorden__8': '2024-12-14 09:10:27', 'estado__8': 'Cancelado', 'usuarioid__8': 987, 'total__9': 128.87, 'fechaorden__9': '2025-01-10 09:10:27', 'estado__9': 'Pendiente', 'usuarioid__9': 500, 'total__10': 186.28, 'fechaorden__10': '2025-02-01 09:10:27', 'estado__10': 'Completado', 'usuarioid__10': 796, 'total__11': 608.73, 'fechaorden__11': '2025-03-31 09:10:27', 'estado__11': 'Completado', 'usuarioid__11': 27, 'total__12': 566.37, 'fechaorden__12': '2024-09-16 09:10:27' ... 3900 parameters truncated ... 'estado__987': 'Cancelado', 'usuarioid__987': 251, 'total__988': 551.9, 'fechaorden__988': '2024-10-11 09:10:27', 'estado__988': 'Completado', 'usuarioid__988': 754, 'total__989': 875.22, 'fechaorden__989': '2024-11-05 09:10:27', 'estado__989': 'Completado', 'usuarioid__989': 410, 'total__990': 911.1, 'fechaorden__990': '2025-02-21 09:10:27', 'estado__990': 'Enviado', 'usuarioid__990': 776, 'total__991': 606.62, 'fechaorden__991': '2025-06-11 09:10:27', 'estado__991': 'Enviado', 'usuarioid__991': 1, 'total__992': 536.61, 'fechaorden__992': '2025-03-11 09:10:27', 'estado__992': 'Completado', 'usuarioid__992': 1, 'total__993': 65.1, 'fechaorden__993': '2025-05-17 09:10:27', 'estado__993': 'Enviado', 'usuarioid__993': 463, 'total__994': 518.02, 'fechaorden__994': '2024-08-18 09:10:27', 'estado__994': 'Cancelado', 'usuarioid__994': 906, 'total__995': 49.21, 'fechaorden__995': '2024-08-13 09:10:27', 'estado__995': 'Pendiente', 'usuarioid__995': 429, 'total__996': 77.95, 'fechaorden__996': '2025-05-05 09:10:27', 'estado__996': 'Enviado', 'usuarioid__996': 62, 'total__997': 217.73, 'fechaorden__997': '2024-10-08 09:10:27', 'estado__997': 'Cancelado', 'usuarioid__997': 360, 'total__998': 624.08, 'fechaorden__998': '2025-01-22 09:10:27', 'estado__998': 'Cancelado', 'usuarioid__998': 80, 'total__999': 420.5, 'fechaorden__999': '2024-11-26 09:10:27', 'estado__999': 'Completado', 'usuarioid__999': 378}
# 2025-07-24 13:40:43,219 INFO sqlalchemy.engine.Engine INSERT INTO ordenes (usuarioid, fechaorden, total, estado) VALUES (%(usuarioid__0)s, %(fechaorden__0)s, %(total__0)s, %(estado__0)s), (%(usuarioid__1)s, %(fechaorden__1)s, %(total__1)s, %(estado__1)s), (%(usuarioid__2)s, %(fechaorden__2)s, %(total__2 ... 75274 characters truncated ... _998)s, %(estado__998)s), (%(usuarioid__999)s, %(fechaorden__999)s, %(total__999)s, %(estado__999)s)
# 2025-07-24 13:40:43,222 INFO sqlalchemy.engine.Engine [insertmanyvalues 9/10 (unordered)] {'total__0': 488.37, 'fechaorden__0': '2025-02-03 09:10:27', 'estado__0': 'Pendiente', 'usuarioid__0': 731, 'total__1': 353.37, 'fechaorden__1': '2025-01-10 09:10:27', 'estado__1': 'Enviado', 'usuarioid__1': 247, 'total__2': 473.83, 'fechaorden__2': '2024-10-06 09:10:27', 'estado__2': 'Pendiente', 'usuarioid__2': 500, 'total__3': 896.52, 'fechaorden__3': '2024-12-28 09:10:27', 'estado__3': 'Cancelado', 'usuarioid__3': 288, 'total__4': 186.01, 'fechaorden__4': '2024-12-04 09:10:27', 'estado__4': 'Completado', 'usuarioid__4': 466, 'total__5': 482.17, 'fechaorden__5': '2024-12-16 09:10:27', 'estado__5': 'Cancelado', 'usuarioid__5': 412, 'total__6': 312.93, 'fechaorden__6': '2025-04-22 09:10:27', 'estado__6': 'Cancelado', 'usuarioid__6': 657, 'total__7': 818.27, 'fechaorden__7': '2025-03-17 09:10:27', 'estado__7': 'Enviado', 'usuarioid__7': 609, 'total__8': 854.99, 'fechaorden__8': '2024-11-27 09:10:27', 'estado__8': 'Cancelado', 'usuarioid__8': 379, 'total__9': 392.7, 'fechaorden__9': '2025-04-23 09:10:27', 'estado__9': 'Completado', 'usuarioid__9': 412, 'total__10': 612.49, 'fechaorden__10': '2024-08-03 09:10:27', 'estado__10': 'Cancelado', 'usuarioid__10': 576, 'total__11': 493.72, 'fechaorden__11': '2025-01-22 09:10:27', 'estado__11': 'Completado', 'usuarioid__11': 948, 'total__12': 231.52, 'fechaorden__12': '2025-01-27 09:10:27' ... 3900 parameters truncated ... 'estado__987': 'Pendiente', 'usuarioid__987': 546, 'total__988': 986.36, 'fechaorden__988': '2024-07-11 09:10:27', 'estado__988': 'Pendiente', 'usuarioid__988': 379, 'total__989': 199.97, 'fechaorden__989': '2024-08-08 09:10:27', 'estado__989': 'Enviado', 'usuarioid__989': 157, 'total__990': 336.51, 'fechaorden__990': '2024-11-10 09:10:27', 'estado__990': 'Pendiente', 'usuarioid__990': 770, 'total__991': 136.83, 'fechaorden__991': '2024-10-07 09:10:27', 'estado__991': 'Pendiente', 'usuarioid__991': 629, 'total__992': 852.03, 'fechaorden__992': '2025-03-23 09:10:27', 'estado__992': 'Enviado', 'usuarioid__992': 576, 'total__993': 602.48, 'fechaorden__993': '2024-11-21 09:10:27', 'estado__993': 'Pendiente', 'usuarioid__993': 163, 'total__994': 713.29, 'fechaorden__994': '2025-04-28 09:10:27', 'estado__994': 'Cancelado', 'usuarioid__994': 229, 'total__995': 409.58, 'fechaorden__995': '2025-05-31 09:10:27', 'estado__995': 'Enviado', 'usuarioid__995': 321, 'total__996': 705.5, 'fechaorden__996': '2024-08-03 09:10:27', 'estado__996': 'Cancelado', 'usuarioid__996': 248, 'total__997': 838.96, 'fechaorden__997': '2025-02-17 09:10:27', 'estado__997': 'Completado', 'usuarioid__997': 93, 'total__998': 851.1, 'fechaorden__998': '2025-01-23 09:10:27', 'estado__998': 'Completado', 'usuarioid__998': 960, 'total__999': 41.92, 'fechaorden__999': '2025-04-17 09:10:27', 'estado__999': 'Completado', 'usuarioid__999': 270}
# 2025-07-24 13:40:43,254 INFO sqlalchemy.engine.Engine INSERT INTO ordenes (usuarioid, fechaorden, total, estado) VALUES (%(usuarioid__0)s, %(fechaorden__0)s, %(total__0)s, %(estado__0)s), (%(usuarioid__1)s, %(fechaorden__1)s, %(total__1)s, %(estado__1)s), (%(usuarioid__2)s, %(fechaorden__2)s, %(total__2 ... 75274 characters truncated ... _998)s, %(estado__998)s), (%(usuarioid__999)s, %(fechaorden__999)s, %(total__999)s, %(estado__999)s)
# ...
# 2025-07-24 13:40:44,778 INFO sqlalchemy.engine.Engine INSERT INTO historialpagos (ordenid, metodopagoid, monto, fechapago, estadopago) VALUES (%(ordenid__0)s, %(metodopagoid__0)s, %(monto__0)s, %(fechapago__0)s, %(estadopago__0)s), (%(ordenid__1)s, %(metodopagoid__1)s, %(monto__1)s, %(fechapago__1)s, %( ... 99186 characters truncated ... , (%(ordenid__999)s, %(metodopagoid__999)s, %(monto__999)s, %(fechapago__999)s, %(estadopago__999)s)
# 2025-07-24 13:40:44,778 INFO sqlalchemy.engine.Engine [insertmanyvalues 7/10 (unordered)] {'estadopago__0': 'Reembolsado', 'metodopagoid__0': 2, 'fechapago__0': '2025-05-19 10:19:16', 'monto__0': 529.69, 'ordenid__0': 6001, 'estadopago__1': 'Reembolsado', 'metodopagoid__1': 6, 'fechapago__1': '2025-05-02 10:19:16', 'monto__1': 566.45, 'ordenid__1': 6002, 'estadopago__2': 'Fallido', 'metodopagoid__2': 5, 'fechapago__2': '2025-05-04 10:19:16', 'monto__2': 470.8, 'ordenid__2': 6003, 'estadopago__3': 'Reembolsado', 'metodopagoid__3': 7, 'fechapago__3': '2025-06-04 10:19:16', 'monto__3': 498.99, 'ordenid__3': 6004, 'estadopago__4': 'Pagado', 'metodopagoid__4': 6, 'fechapago__4': '2025-04-11 10:19:16', 'monto__4': 145.64, 'ordenid__4': 6005, 'estadopago__5': 'Procesando', 'metodopagoid__5': 2, 'fechapago__5': '2025-06-20 10:19:16', 'monto__5': 554.91, 'ordenid__5': 6006, 'estadopago__6': 'Reembolsado', 'metodopagoid__6': 5, 'fechapago__6': '2025-04-21 10:19:16', 'monto__6': 642.11, 'ordenid__6': 6007, 'estadopago__7': 'Pagado', 'metodopagoid__7': 3, 'fechapago__7': '2025-04-25 10:19:16', 'monto__7': 723.23, 'ordenid__7': 6008, 'estadopago__8': 'Procesando', 'metodopagoid__8': 7, 'fechapago__8': '2025-04-21 10:19:16', 'monto__8': 295.43, 'ordenid__8': 6009, 'estadopago__9': 'Procesando', 'metodopagoid__9': 6, 'fechapago__9': '2025-06-01 10:19:16', 'monto__9': 351.73, 'ordenid__9': 6010 ... 4900 parameters truncated ... 'estadopago__990': 'Reembolsado', 'metodopagoid__990': 2, 'fechapago__990': '2025-06-28 10:19:16', 'monto__990': 528.78, 'ordenid__990': 6991, 'estadopago__991': 'Procesando', 'metodopagoid__991': 6, 'fechapago__991': '2025-06-28 10:19:16', 'monto__991': 651.17, 'ordenid__991': 6992, 'estadopago__992': 'Fallido', 'metodopagoid__992': 1, 'fechapago__992': '2025-04-10 10:19:16', 'monto__992': 521.2, 'ordenid__992': 6993, 'estadopago__993': 'Pagado', 'metodopagoid__993': 7, 'fechapago__993': '2025-04-26 10:19:16', 'monto__993': 141.65, 'ordenid__993': 6994, 'estadopago__994': 'Reembolsado', 'metodopagoid__994': 7, 'fechapago__994': '2025-04-27 10:19:16', 'monto__994': 571.34, 'ordenid__994': 6995, 'estadopago__995': 'Reembolsado', 'metodopagoid__995': 5, 'fechapago__995': '2025-04-25 10:19:16', 'monto__995': 223.21, 'ordenid__995': 6996, 'estadopago__996': 'Procesando', 'metodopagoid__996': 4, 'fechapago__996': '2025-05-31 10:19:16', 'monto__996': 210.59, 'ordenid__996': 6997, 'estadopago__997': 'Fallido', 'metodopagoid__997': 5, 'fechapago__997': '2025-04-03 10:19:16', 'monto__997': 408.91, 'ordenid__997': 6998, 'estadopago__998': 'Fallido', 'metodopagoid__998': 5, 'fechapago__998': '2025-04-27 10:19:16', 'monto__998': 678.3, 'ordenid__998': 6999, 'estadopago__999': 'Pagado', 'metodopagoid__999': 1, 'fechapago__999': '2025-05-21 10:19:16', 'monto__999': 327.1, 'ordenid__999': 7000}
# 2025-07-24 13:40:44,808 INFO sqlalchemy.engine.Engine INSERT INTO historialpagos (ordenid, metodopagoid, monto, fechapago, estadopago) VALUES (%(ordenid__0)s, %(metodopagoid__0)s, %(monto__0)s, %(fechapago__0)s, %(estadopago__0)s), (%(ordenid__1)s, %(metodopagoid__1)s, %(monto__1)s, %(fechapago__1)s, %( ... 99186 characters truncated ... , (%(ordenid__999)s, %(metodopagoid__999)s, %(monto__999)s, %(fechapago__999)s, %(estadopago__999)s)
# 2025-07-24 13:40:44,810 INFO sqlalchemy.engine.Engine [insertmanyvalues 8/10 (unordered)] {'estadopago__0': 'Reembolsado', 'metodopagoid__0': 2, 'fechapago__0': '2025-05-13 10:19:16', 'monto__0': 867.97, 'ordenid__0': 7001, 'estadopago__1': 'Reembolsado', 'metodopagoid__1': 7, 'fechapago__1': '2025-05-11 10:19:16', 'monto__1': 887.38, 'ordenid__1': 7002, 'estadopago__2': 'Fallido', 'metodopagoid__2': 4, 'fechapago__2': '2025-04-21 10:19:16', 'monto__2': 599.64, 'ordenid__2': 7003, 'estadopago__3': 'Fallido', 'metodopagoid__3': 1, 'fechapago__3': '2025-04-10 10:19:16', 'monto__3': 570.38, 'ordenid__3': 7004, 'estadopago__4': 'Reembolsado', 'metodopagoid__4': 1, 'fechapago__4': '2025-06-07 10:19:16', 'monto__4': 706.38, 'ordenid__4': 7005, 'estadopago__5': 'Fallido', 'metodopagoid__5': 4, 'fechapago__5': '2025-06-25 10:19:16', 'monto__5': 518.09, 'ordenid__5': 7006, 'estadopago__6': 'Procesando', 'metodopagoid__6': 6, 'fechapago__6': '2025-04-30 10:19:16', 'monto__6': 105.35, 'ordenid__6': 7007, 'estadopago__7': 'Fallido', 'metodopagoid__7': 7, 'fechapago__7': '2025-06-30 10:19:16', 'monto__7': 537.23, 'ordenid__7': 7008, 'estadopago__8': 'Pagado', 'metodopagoid__8': 1, 'fechapago__8': '2025-05-19 10:19:16', 'monto__8': 580.53, 'ordenid__8': 7009, 'estadopago__9': 'Procesando', 'metodopagoid__9': 6, 'fechapago__9': '2025-06-10 10:19:16', 'monto__9': 449.66, 'ordenid__9': 7010 ... 4900 parameters truncated ... 'estadopago__990': 'Fallido', 'metodopagoid__990': 6, 'fechapago__990': '2025-04-05 10:19:16', 'monto__990': 748.26, 'ordenid__990': 7991, 'estadopago__991': 'Procesando', 'metodopagoid__991': 6, 'fechapago__991': '2025-06-05 10:19:16', 'monto__991': 183.4, 'ordenid__991': 7992, 'estadopago__992': 'Fallido', 'metodopagoid__992': 4, 'fechapago__992': '2025-05-21 10:19:16', 'monto__992': 426.85, 'ordenid__992': 7993, 'estadopago__993': 'Procesando', 'metodopagoid__993': 5, 'fechapago__993': '2025-06-10 10:19:16', 'monto__993': 690.81, 'ordenid__993': 7994, 'estadopago__994': 'Pagado', 'metodopagoid__994': 3, 'fechapago__994': '2025-04-05 10:19:16', 'monto__994': 727.79, 'ordenid__994': 7995, 'estadopago__995': 'Pagado', 'metodopagoid__995': 5, 'fechapago__995': '2025-05-15 10:19:16', 'monto__995': 577.88, 'ordenid__995': 7996, 'estadopago__996': 'Procesando', 'metodopagoid__996': 3, 'fechapago__996': '2025-06-20 10:19:16', 'monto__996': 418.47, 'ordenid__996': 7997, 'estadopago__997': 'Fallido', 'metodopagoid__997': 7, 'fechapago__997': '2025-05-17 10:19:16', 'monto__997': 344.64, 'ordenid__997': 7998, 'estadopago__998': 'Procesando', 'metodopagoid__998': 4, 'fechapago__998': '2025-06-23 10:19:16', 'monto__998': 437.02, 'ordenid__998': 7999, 'estadopago__999': 'Reembolsado', 'metodopagoid__999': 4, 'fechapago__999': '2025-06-15 10:19:16', 'monto__999': 408.36, 'ordenid__999': 8000}
# 2025-07-24 13:40:44,839 INFO sqlalchemy.engine.Engine INSERT INTO historialpagos (ordenid, metodopagoid, monto, fechapago, estadopago) VALUES (%(ordenid__0)s, %(metodopagoid__0)s, %(monto__0)s, %(fechapago__0)s, %(estadopago__0)s), (%(ordenid__1)s, %(metodopagoid__1)s, %(monto__1)s, %(fechapago__1)s, %( ... 99186 characters truncated ... , (%(ordenid__999)s, %(metodopagoid__999)s, %(monto__999)s, %(fechapago__999)s, %(estadopago__999)s)
# 2025-07-24 13:40:44,840 INFO sqlalchemy.engine.Engine [insertmanyvalues 9/10 (unordered)] {'estadopago__0': 'Procesando', 'metodopagoid__0': 5, 'fechapago__0': '2025-05-31 10:19:16', 'monto__0': 615.7, 'ordenid__0': 8001, 'estadopago__1': 'Pagado', 'metodopagoid__1': 6, 'fechapago__1': '2025-06-23 10:19:16', 'monto__1': 444.05, 'ordenid__1': 8002, 'estadopago__2': 'Pagado', 'metodopagoid__2': 5, 'fechapago__2': '2025-05-10 10:19:16', 'monto__2': 122.75, 'ordenid__2': 8003, 'estadopago__3': 'Reembolsado', 'metodopagoid__3': 7, 'fechapago__3': '2025-06-29 10:19:16', 'monto__3': 116.96, 'ordenid__3': 8004, 'estadopago__4': 'Fallido', 'metodopagoid__4': 3, 'fechapago__4': '2025-04-07 10:19:16', 'monto__4': 842.07, 'ordenid__4': 8005, 'estadopago__5': 'Pagado', 'metodopagoid__5': 2, 'fechapago__5': '2025-05-16 10:19:16', 'monto__5': 736.32, 'ordenid__5': 8006, 'estadopago__6': 'Fallido', 'metodopagoid__6': 7, 'fechapago__6': '2025-06-25 10:19:16', 'monto__6': 960.47, 'ordenid__6': 8007, 'estadopago__7': 'Reembolsado', 'metodopagoid__7': 1, 'fechapago__7': '2025-04-20 10:19:16', 'monto__7': 159.44, 'ordenid__7': 8008, 'estadopago__8': 'Pagado', 'metodopagoid__8': 6, 'fechapago__8': '2025-05-12 10:19:16', 'monto__8': 812.65, 'ordenid__8': 8009, 'estadopago__9': 'Fallido', 'metodopagoid__9': 5, 'fechapago__9': '2025-06-16 10:19:16', 'monto__9': 402.37, 'ordenid__9': 8010 ... 4900 parameters truncated ... 'estadopago__990': 'Pagado', 'metodopagoid__990': 7, 'fechapago__990': '2025-06-11 10:19:16', 'monto__990': 792.14, 'ordenid__990': 8991, 'estadopago__991': 'Reembolsado', 'metodopagoid__991': 5, 'fechapago__991': '2025-05-22 10:19:16', 'monto__991': 536.07, 'ordenid__991': 8992, 'estadopago__992': 'Reembolsado', 'metodopagoid__992': 6, 'fechapago__992': '2025-05-12 10:19:16', 'monto__992': 418.03, 'ordenid__992': 8993, 'estadopago__993': 'Reembolsado', 'metodopagoid__993': 6, 'fechapago__993': '2025-05-29 10:19:16', 'monto__993': 359.33, 'ordenid__993': 8994, 'estadopago__994': 'Reembolsado', 'metodopagoid__994': 1, 'fechapago__994': '2025-06-14 10:19:16', 'monto__994': 271.65, 'ordenid__994': 8995, 'estadopago__995': 'Pagado', 'metodopagoid__995': 4, 'fechapago__995': '2025-04-20 10:19:16', 'monto__995': 290.82, 'ordenid__995': 8996, 'estadopago__996': 'Fallido', 'metodopagoid__996': 7, 'fechapago__996': '2025-05-11 10:19:16', 'monto__996': 590.75, 'ordenid__996': 8997, 'estadopago__997': 'Reembolsado', 'metodopagoid__997': 2, 'fechapago__997': '2025-05-13 10:19:16', 'monto__997': 199.66, 'ordenid__997': 8998, 'estadopago__998': 'Reembolsado', 'metodopagoid__998': 5, 'fechapago__998': '2025-06-30 10:19:16', 'monto__998': 916.24, 'ordenid__998': 8999, 'estadopago__999': 'Procesando', 'metodopagoid__999': 3, 'fechapago__999': '2025-04-10 10:19:16', 'monto__999': 759.21, 'ordenid__999': 9000}
# 2025-07-24 13:40:44,877 INFO sqlalchemy.engine.Engine INSERT INTO historialpagos (ordenid, metodopagoid, monto, fechapago, estadopago) VALUES (%(ordenid__0)s, %(metodopagoid__0)s, %(monto__0)s, %(fechapago__0)s, %(estadopago__0)s), (%(ordenid__1)s, %(metodopagoid__1)s, %(monto__1)s, %(fechapago__1)s, %( ... 99186 characters truncated ... , (%(ordenid__999)s, %(metodopagoid__999)s, %(monto__999)s, %(fechapago__999)s, %(estadopago__999)s)
# 2025-07-24 13:40:44,879 INFO sqlalchemy.engine.Engine [insertmanyvalues 10/10 (unordered)] {'estadopago__0': 'Procesando', 'metodopagoid__0': 3, 'fechapago__0': '2025-05-26 10:19:16', 'monto__0': 964.84, 'ordenid__0': 9001, 'estadopago__1': 'Reembolsado', 'metodopagoid__1': 2, 'fechapago__1': '2025-04-23 10:19:16', 'monto__1': 630.59, 'ordenid__1': 9002, 'estadopago__2': 'Fallido', 'metodopagoid__2': 5, 'fechapago__2': '2025-04-07 10:19:16', 'monto__2': 549.66, 'ordenid__2': 9003, 'estadopago__3': 'Fallido', 'metodopagoid__3': 5, 'fechapago__3': '2025-04-30 10:19:16', 'monto__3': 751.66, 'ordenid__3': 9004, 'estadopago__4': 'Fallido', 'metodopagoid__4': 4, 'fechapago__4': '2025-06-08 10:19:16', 'monto__4': 694.13, 'ordenid__4': 9005, 'estadopago__5': 'Reembolsado', 'metodopagoid__5': 7, 'fechapago__5': '2025-05-08 10:19:16', 'monto__5': 916.81, 'ordenid__5': 9006, 'estadopago__6': 'Pagado', 'metodopagoid__6': 3, 'fechapago__6': '2025-04-11 10:19:16', 'monto__6': 518.62, 'ordenid__6': 9007, 'estadopago__7': 'Reembolsado', 'metodopagoid__7': 4, 'fechapago__7': '2025-06-15 10:19:16', 'monto__7': 765.95, 'ordenid__7': 9008, 'estadopago__8': 'Fallido', 'metodopagoid__8': 1, 'fechapago__8': '2025-05-31 10:19:16', 'monto__8': 668.87, 'ordenid__8': 9009, 'estadopago__9': 'Pagado', 'metodopagoid__9': 7, 'fechapago__9': '2025-06-30 10:19:16', 'monto__9': 149.5, 'ordenid__9': 9010 ... 4900 parameters truncated ... 'estadopago__990': 'Fallido', 'metodopagoid__990': 4, 'fechapago__990': '2025-06-25 10:19:16', 'monto__990': 436.19, 'ordenid__990': 9991, 'estadopago__991': 'Fallido', 'metodopagoid__991': 1, 'fechapago__991': '2025-04-21 10:19:16', 'monto__991': 931.09, 'ordenid__991': 9992, 'estadopago__992': 'Reembolsado', 'metodopagoid__992': 6, 'fechapago__992': '2025-04-06 10:19:16', 'monto__992': 993.22, 'ordenid__992': 9993, 'estadopago__993': 'Pagado', 'metodopagoid__993': 5, 'fechapago__993': '2025-05-21 10:19:16', 'monto__993': 496.44, 'ordenid__993': 9994, 'estadopago__994': 'Reembolsado', 'metodopagoid__994': 3, 'fechapago__994': '2025-06-02 10:19:16', 'monto__994': 795.24, 'ordenid__994': 9995, 'estadopago__995': 'Reembolsado', 'metodopagoid__995': 3, 'fechapago__995': '2025-06-14 10:19:16', 'monto__995': 997.53, 'ordenid__995': 9996, 'estadopago__996': 'Pagado', 'metodopagoid__996': 4, 'fechapago__996': '2025-04-04 10:19:16', 'monto__996': 643.26, 'ordenid__996': 9997, 'estadopago__997': 'Reembolsado', 'metodopagoid__997': 6, 'fechapago__997': '2025-05-10 10:19:16', 'monto__997': 704.11, 'ordenid__997': 9998, 'estadopago__998': 'Fallido', 'metodopagoid__998': 5, 'fechapago__998': '2025-05-29 10:19:16', 'monto__998': 837.1, 'ordenid__998': 9999, 'estadopago__999': 'Reembolsado', 'metodopagoid__999': 2, 'fechapago__999': '2025-04-12 10:19:16', 'monto__999': 316.47, 'ordenid__999': 10000}
# 2025-07-24 13:40:44,906 INFO sqlalchemy.engine.Engine COMMIT
